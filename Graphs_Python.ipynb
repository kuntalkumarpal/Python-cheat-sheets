# %% [markdown]
# # BAR GRAPH

# %% [markdown]
# ### Vertical Bar with two towers

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['Abductive NLI', 'Physical IQA', 'Social IQA']
men_means = [20, 48, 30]
women_means = [25, 52, 34]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Good K')
rects2 = ax.bar(x + width/2, women_means, width, label='Insufficient K')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('# of Samples')
ax.set_title('Correct Prediction Analysis')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# %% [markdown]
# ### Vertical Bar graph with 4 towers

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['Abductive NLI', 'Physical IQA', 'Social IQA']
noK = [0, 48, 36]
correctOptK = [39, 15, 35]
exactK = [62,52,0]
relatedK = [24,0,29]


x = np.arange(len(labels))  # the label locations
width = 0.21  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 3*width/2, noK, width, label='No K')
rects2 = ax.bar(x + width/2, correctOptK, width, label='K across True Option')
rects1 = ax.bar(x - width/2, exactK, width, label='Exact K')
rects2 = ax.bar(x + 3*width/2, relatedK, width, label='Related K')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('# of Samples')
ax.set_title('Correct Prediction Analysis')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

ax.set_ylim([0, 80])
# Out:
# (0, 80)

# %%
fig.savefig("Correct.png")

# %% [markdown]
# ### Histogram

# %%
# bins = [1, 2, 3, 4, 5]
processed_data = [164.0, 160.0, 156.0, 152.0, 150.0, 145.0, 139.0, 131.0, 124.0, 122.0, 120.0, 115.0, 109.0, 101.0, 89.0, 81.0, 77.0, 75.0, 74.0, 74.0, 76.0, 78.0, 79.0, 79.0, 78.0, 75.0, 75.0, 74.0, 75.0, 77.0]
print(processed_data)
hist, bins = np.histogram(np.array(processed_data),bins=5)
# Out:
# [164.0, 160.0, 156.0, 152.0, 150.0, 145.0, 139.0, 131.0, 124.0, 122.0, 120.0, 115.0, 109.0, 101.0, 89.0, 81.0, 77.0, 75.0, 74.0, 74.0, 76.0, 78.0, 79.0, 79.0, 78.0, 75.0, 75.0, 74.0, 75.0, 77.0]

# %%
from matplotlib import pyplot  as  plt
plt.figure()
print(hist,bins)
plt.bar(bins[:-1], hist, width=1)
# Out:
# [16  2  4  3  5] [ 74.  92. 110. 128. 146. 164.]
# <BarContainer object of 5 artists>

# %% [markdown]
# ### [Pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
import seaborn as sns
import numpy as np; import pandas as pd
sns.set(style="ticks", color_codes=True)
# iris = sns.load_dataset("iris")
g = sns.pairplot(pd.DataFrame(np.random.rand(3,3)))

# %% [markdown]
# # Time Series

# %%
plt.style.use("seaborn")
from matplotlib import pyplot as plt
from matplotlib import dates as dt
idx = 32
time = [737225.479988426, 737225.483460648, 737225.48693287, 737225.490405093, 737225.493877315, 737225.497349537, 737225.5008217591, 737225.5042939809, 737225.5077662041, 737225.511238426]
data = [92.0, 91.0, 90.0, 91.0, 91.0, 97.0, 99.0, 98.0, 99.0, 99.0]
# print(processed_data[idx])
plt.plot_date(time,data, linestyle='solid')
plt.gcf().autofmt_xdate()

# %% [markdown]
# ### PointPlot

# %%
# final = pd.concat([pd.concat([tok_len_histogram,tok_train]),tok_test])
import seaborn as sns
sns.set(style="whitegrid")
#Final is pandas dataframe

# %%
ax = sns.pointplot(x="Length", y="LogCount", hue="Type",
                       data=final)

# %% [markdown]
# ### Lineplot

# %%
ax = sns.lineplot(x="Length", y="Count", hue="Type",
                       data=final)

# %% [markdown]
# ### Stem Plot

# %%
plt.figure()
data = [92.0, 91.0, 90.0, 91.0, 91.0, 97.0, 99.0, 98.0, 99.0, 99.0]
plt.stem(data)
# Out:
# /Users/kuntal/miniconda3/envs/work/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <StemContainer object of 3 artists>

# %% [markdown]
# ### Radar / Spider Plot

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# df=pd.read_csv("../pokemon/Pokemon.csv")

iiiid = 4
labels=final_data.columns[feature_idx[iiiid]]
stats=vals[iiiid]

# %%
angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False)
# close the plot
stats=np.concatenate((stats,[stats[0]]))  # Closed
angles=np.concatenate((angles,[angles[0]]))  # Closed

# %%
fig=plt.figure()
ax = fig.add_subplot(111, polar=True)   # Set polar axis
ax.plot(angles, stats, 'o-', linewidth=2)  # Draw the plot (or the frame on the radar chart)
ax.fill(angles, stats, alpha=0.25)  #Fulfill the area
ax.set_thetagrids(angles * 180/np.pi, labels)  # Set the label for each axis
ax.set_title("PCA_"+str(iiiid))  # Set the pokemon's name as the title
#ax.set_rlim(0,250)
ax.grid(True)

# %% [markdown]
# ### Line Plot - seaborn (Loss function of DL)

# %%
import matplotlib.pyplot as plt
# % matplotlib inline

import seaborn as sns

# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

# Plot the learning curve.
plt.plot([40,30,4,1,0], 'b-o')

# Label the plot.
plt.title("Training loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.show()

# %% [markdown]
# ### Multi-Bar Plot

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()

labels = ['Chemical', 'Disease','Gene/Protein',  'Problem', 'Test', 'Treatment']
nok = [88.73,
84.86,
70.51,
92.39,
92.67,
91.88]
qk=[91.49,
85.68,
85.44,
93.73,
94.38,
93.19]
etk=[89.66,
84.60,
82.74,
92.69,
92.83,
91.72]
dk=[90.01,
85.75,
75.75,
92.43,
92.54,
91.75]
egk=[90.22,
85.04,
82.85,
92.85,
92.84,
92.13]

x = np.arange(len(labels))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 2*width, nok, width, label='No Knowledge')
rects2 = ax.bar(x - width, dk, width, label='Definition')
rects3 = ax.bar(x, egk, width, label='Example')
rects4 = ax.bar(x + width, etk, width, label='Entity Type')
rects5 = ax.bar(x + 2*width, qk, width, label='Question')

# sns.palplot(sns.color_palette("RdBu", n_colors=4))

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('F1-Score')
# ax.set_title('Correct Prediction Analysis')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)

plt.ylim(50, 100)

# ax.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=1)

ax.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=3, mode="expand", borderaxespad=0.)
# plt.legend(bbox_to_anchor=(1, 1),
#            bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()

labels = ['Chemical', 'Disease','Gene/Protein',  'Problem', 'Test', 'Treatment']
nok = [89.04,
83.17,
67.33,
91.95,
92.12,
91.78]
qk=[91.84,
83.48,
84.19,
93.28,
94.09,
92.91]
etk=[90.25,
82.9,
81.79,
92.21,
92.45,
91.4]
dk=[90.28,
83.88,
72.56,
91.69,
91.83,
91.31]
egk=[90.81,
82.65,
81.32,
92.47,
91.81,
92.14]

x = np.arange(len(labels))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 2*width, nok, width, label='No Knowledge')
rects2 = ax.bar(x - width, dk, width, label='Definition')
rects3 = ax.bar(x, egk, width, label='Example')
rects4 = ax.bar(x + width, etk, width, label='Entity Type')
rects5 = ax.bar(x + 2*width, qk, width, label='Question')

# sns.palplot(sns.color_palette("RdBu", n_colors=4))

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Precision')
# ax.set_title('Correct Prediction Analysis')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)

plt.ylim(50, 100)

# ax.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=1)

ax.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=3, mode="expand", borderaxespad=0.)
# plt.legend(bbox_to_anchor=(1, 1),
#            bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()

labels = ['Chemical', 'Disease','Gene/Protein',  'Problem', 'Test', 'Treatment']
nok = [88.42,
86.62,
74.01,
92.83,
93.23,
91.98]
qk=[91.15,
88,
86.73,
94.18,
94.67,
93.47]
etk=[89.07,
86.38,
83.72,
93.17,
93.21,
92.06]
dk=[89.73,
87.72,
79.24,
93.17,
93.25,
92.2]
egk=[89.63,
87.58,
84.45,
93.23,
93.9,
92.12]

x = np.arange(len(labels))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 2*width, nok, width, label='No Knowledge')
rects2 = ax.bar(x - width, dk, width, label='Definition')
rects3 = ax.bar(x, egk, width, label='Example')
rects4 = ax.bar(x + width, etk, width, label='Entity Type')
rects5 = ax.bar(x + 2*width, qk, width, label='Question')

# sns.palplot(sns.color_palette("RdBu", n_colors=4))

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Recall')
# ax.set_title('Correct Prediction Analysis')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)

plt.ylim(70, 100)

# ax.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=1)

ax.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=3, mode="expand", borderaxespad=0.)
# plt.legend(bbox_to_anchor=(1, 1),
#            bbox_transform=plt.gcf().transFigure)

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# sns.set(rc={'figure.figsize':(30,40)})
sns.set(font_scale = 3,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

x = ['2%',
'5%',
'10%',
'20%',
'30%',
'50%',
'75%',
'100%']
question=[0.7791,
0.8372,
0.8611,
0.8749,
0.8822,
0.8899,
0.8927,
0.8932]
definition = [0.7545,
0.7983,
0.8203,
0.8355,
0.8382,
0.8411,
0.851,
0.8554]
entity_type=[0.7814,
0.8163,
0.8357,
0.8528,
0.8536,
0.8625,
0.8714,
0.877]
example=[0.7909,
0.8261,
0.845,
0.8581,
0.8647,
0.8709,
0.876,
0.8795]

biobert_question = [0.7873,
0.8347,
0.8618,
0.8693,
0.8822,
0.881,
0.8939,
0.8944]
mimicbert_question = [0.6946,
0.77,
0.8081,
0.8386,
0.8501,
0.8642,
0.8738,
0.8794]

all_k =[0.7837,
0.8391,
0.8631,
0.8757,
0.8835,
0.893,
0.8967,
0.898,]

question = [round(100*each,2) for each in question]
definition = [round(100*each,2) for each in definition]
entity_type = [round(100*each,2) for each in entity_type]
example  = [round(100*each,2) for each in example]
biobert_question = [round(100*each,2) for each in biobert_question]
mimicbert_question  = [round(100*each,2) for each in mimicbert_question]
all_k  = [round(100*each,2) for each in all_k]

f1_data = pd.DataFrame({
    'DataSize': x, 
    'Question': question,
    'Definition': definition,
    'Entity Type':entity_type,
    'Example': example,
    'All':all_k})
##------------------------------------------------------------------------------------------------------------
question=[0.7541,
0.8338,
0.8561,
0.8722,
0.8801,
0.8903,
0.8954,
0.8968]
definition = [0.7538,
0.7839,
0.8144,
0.8313,
0.8322,
0.8393,
0.8421,
0.8514]
entity_type=[0.7784,
0.8184,
0.8347,
0.8586,
0.8532,
0.8644,
0.8742,
0.8797]
example=[0.8114,
0.8316,
0.8436,
0.8648,
0.8718,
0.8725,
0.8806,
0.8844]

biobert_question = [0.7861,
0.828,
0.8538,
0.8718,
0.8841,
0.8798,
0.8943,
0.8946]
mimicbert_question = [0.7153,
0.7644,
0.8151,
0.8438,
0.8524,
0.8658,
0.8791,
0.8857]

all_k =[0.7849,
0.8396,
0.8681,
0.8837,
0.8895,
0.8964,
0.8988,
0.9003]

question = [round(100*each,2) for each in question]
definition = [round(100*each,2) for each in definition]
entity_type = [round(100*each,2) for each in entity_type]
example  = [round(100*each,2) for each in example]
biobert_question = [round(100*each,2) for each in biobert_question]
mimicbert_question  = [round(100*each,2) for each in mimicbert_question]
all_k  = [round(100*each,2) for each in all_k]
p_data = pd.DataFrame({
    'DataSize': x, 
    'Question': question,
    'Definition': definition,
    'Entity Type':entity_type,
    'Example': example,
    'All':all_k})

##------------------------------------------------------------------------------------------------------------
question=[0.8057,
0.8407,
0.8662,
0.8776,
0.8844,
0.8895,
0.8901,
0.8896]
definition = [0.7553,
0.8132,
0.8263,
0.8397,
0.8443,
0.843,
0.8601,
0.8594]
entity_type=[0.7844,
0.8143,
0.8368,
0.847,
0.854,
0.8606,
0.8686,
0.8744]
example=[0.7715,
0.8207,
0.8464,
0.8516,
0.8576,
0.8694,
0.8716,
0.8748]

biobert_question = [0.7885,
0.8416,
0.8699,
0.8668,
0.8803,
0.8821,
0.8935,
0.8942]
mimicbert_question = [0.675,
0.7757,
0.8012,
0.8335,
0.8479,
0.8626,
0.8686,
0.8732]
all_k = [0.7826,
0.8386,
0.8582,
0.8828,
0.8877,
0.8923,
0.8946,
0.8956,]

question = [round(100*each,2) for each in question]
definition = [round(100*each,2) for each in definition]
entity_type = [round(100*each,2) for each in entity_type]
example  = [round(100*each,2) for each in example]
biobert_question = [round(100*each,2) for each in biobert_question]
mimicbert_question  = [round(100*each,2) for each in mimicbert_question]
all_k  = [round(100*each,2) for each in all_k]
r_data = pd.DataFrame({
    'DataSize': x, 
    'Question': question,
    'Definition': definition,
    'Entity Type':entity_type,
    'Example': example,
    'All':all_k})
f, (ax) = plt.subplots(nrows=1, ncols=3, figsize=(48, 10))
# f.set_ylim([70,95])
# print(ax)
for each in range(3):
    ax[each].set(ylim=(75, 91))
# ax.grid(True)
# sns.set_style("darkgrid")
marks = ['s','+','*','d','o']
g1 = sns.pointplot(x='DataSize', y='F1-Score', hue='Knowledge Type', 
              data=pd.melt(f1_data, ['DataSize'],var_name="Knowledge Type",value_name="F1-Score"),ax=ax[0],markers=marks)
g2 = sns.pointplot(x='DataSize', y='Precision', hue='Knowledge Type', 
              data=pd.melt(p_data, ['DataSize'],var_name="Knowledge Type",value_name="Precision"),ax=ax[1],markers=marks)
g3 = sns.pointplot(x='DataSize', y='Recall', hue='Knowledge Type', linewidth=18,
              data=pd.melt(r_data, ['DataSize'],var_name="Knowledge Type",value_name="Recall"),ax=ax[2],markers=marks) #markers = ['s','D','d','+','o']
# g1.legend_.remove()
# g2.legend_.remove()
# g3.legend_.remove()

handles, labels = ax[2].get_legend_handles_labels()#Common legend for all subplot

ylabels = ["F-Measure", "Precision","Recall"]
for e in range(3):
    ax[e].set_xlabel("DataSize",fontsize=40)
    ax[e].set_ylabel(ylabels[e],fontsize=40)
#     leg = ax[e].legend(markerscale=2.0)
    ax[e].legend().get_frame().set_linewidth(7)
    ax[e].legend().get_frame().set_edgecolor('black')
    for axis in ['top','bottom','left','right']:
        ax[e].spines[axis].set_linewidth(1)
        ax[e].spines[axis].set_color('black')
    
#x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=1.0,bbox_to_anchor=(0.06, 0.91, 0.78, .05), loc='center',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
f.savefig('Learning_curve3.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %%
pd.melt(data_preproc, ['DataSize'],var_name="Knowledge Type",value_name="F1-Score")
# Out:
#     DataSize Knowledge Type  F1-Score
# 0          2       Question     77.91
# 1          5       Question     83.72
# 2         10       Question     86.11
# 3         20       Question     87.49
# 4         30       Question     88.22
# 5         50       Question     88.99
# 6         75       Question     89.27
# 7        100       Question     89.32
# 8          2     Definition     75.45
# 9          5     Definition     79.83
# 10        10     Definition     82.03
# 11        20     Definition     83.55
# 12        30     Definition     83.82
# 13        50     Definition     84.11
# 14        75     Definition     85.10
# 15       100     Definition     85.54
# 16         2    entity_type     78.14
# 17         5    entity_type     81.63
# 18        10    entity_type     83.57
# 19        20    entity_type     85.28
# 20        30    entity_type     85.36
# 21        50    entity_type     86.25
# 22        75    entity_type     87.14
# 23       100    entity_type     87.70
# ...

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set(style="whitegrid")
x = ['Precision', 'Recall', 'F1-Score']
precision = [0.756,
0.7139,
0.8634,
0.9339,
0.9451,
0.9265]
recall=[0.7596,
0.7005,
0.8231,
0.9549,
0.9559,
0.9572]
f1=[0.7578,
0.7072,
0.8428,
0.9443,
0.9504,
0.9416]
precision = [round(100*each,2) for each in precision]
recall = [round(100*each,2) for each in recall]
f1  = [round(100*each,2) for each in f1]

r_data = pd.DataFrame({
    'Performance': x, 
    'Precision': precision,
    'Recall':recall,
    'f1': f1})
f, (ax) = plt.subplots(nrows=1, ncols=1, figsize=(16, 3))
# f.set_ylim([70,95])
# print(ax)
for each in range(3):
    ax[each].set(ylim=(65, 100))
# ax.grid(True)
# sns.set_style("darkgrid")
sns.pointplot(x='Type', y='Performance', hue='Entity Type', 
              data=pd.melt(f1_data, ['Type'],var_name="Entity Type",value_name="Performance"),ax=ax[0],markers=".")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-846fa3c8f1ad> in <module>
#      31     'Precision': precision,
#      32     'Recall':recall,
# ---> 33     'f1': f1})
#      34 f, (ax) = plt.subplots(nrows=1, ncols=1, figsize=(16, 3))
#      35 # f.set_ylim([70,95])
#
# ~/miniconda3/envs/work/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/miniconda3/envs/work/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()
# sns.set(style="whitegrid")

labels = ['Precision', 'Recall', 'F1-Score']
chemical =  [75.6,75.96,75.78]
disease = [71.39,70.05,70.72]
geneprotein = [86.34,82.31,84.28]
problem = [93.39,95.49,94.43]
test = [94.51,95.59,95.04]
treatment = [92.65,95.72,94.16]
# precision = [0.756,
# 0.7139,
# 0.8634,
# 0.9339,
# 0.9451,
# 0.9265]
# recall=[0.7596,
# 0.7005,
# 0.8231,
# 0.9549,
# 0.9559,
# 0.9572]
# f1=[0.7578,
# 0.7072,
# 0.8428,
# 0.9443,
# 0.9504,
# 0.9416]
# precision = [round(100*each,2) for each in precision]
# recall = [round(100*each,2) for each in recall]
# f1  = [round(100*each,2) for each in f1]


x = np.arange(len(labels))  # the label locations
width = 0.13  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 2*width, disease, width, label='Disease')
rects2 = ax.bar(x - width, chemical, width, label='Chemical')
rects3 = ax.bar(x , geneprotein, width, label='Gene/Protein')
rects4 = ax.bar(x + width, treatment, width, label='Treatment')
rects5 = ax.bar(x + 2*width, problem, width, label='Problem')
rects6 = ax.bar(x + 3*width, test, width, label='Test')

# sns.palplot(sns.color_palette("RdBu", n_colors=4))

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Performance')
# ax.set_title('Correct Prediction Analysis')
ax.set_xticks(x)
ax.set_xticklabels(labels)

plt.ylim(60, 100)

# ax.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=1)

ax.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=3, mode="expand", borderaxespad=0.)
# plt.legend(bbox_to_anchor=(1, 1),
#            bbox_transform=plt.gcf().transFigure)

# %% [markdown]
# ### Flow-Graph

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# sns.set(rc={'figure.figsize':(30,40)})
sns.set(font_scale = 2.5,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

x = ['W-all','W5','W4','W3'][::-1]

bert=[0.4846,0.527967,0.544161,0.58132]
bert_pt = [0.435233,0.526038,0.550633,0.633427]
roberta=[0.480783,0.513455,0.561717,0.614533]
roberta_pt=[0.402913,0.541899,0.579752,0.629359]


bert = [round(100*each,2) for each in bert][::-1]
bert_pt = [round(100*each,2) for each in bert_pt][::-1]
roberta = [round(100*each,2) for each in roberta][::-1]
roberta_pt  = [round(100*each,2) for each in roberta_pt][::-1]

f1_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-GCN': bert,
    'PT-BERT-GCN': bert_pt,
    'ROBERTA-GCN':roberta,
    'PT-ROBERTA-GCN': roberta_pt})
##------------------------------------------------------------------------------------------------------------

bert=[0.551684,0.527397,0.551405,0.631217]
bert_pt = [0.558026,0.49942,0.558108,0.623193]
roberta=[0.424933,0.514585,0.560865,0.62002]
roberta_pt=[0.505591,0.53661,0.601245,0.645562]


bert = [round(each,2) for each in bert][::-1]
bert_pt = [round(each,2) for each in bert_pt][::-1]
roberta = [round(each,2) for each in roberta][::-1]
roberta_pt  = [round(each,2) for each in roberta_pt][::-1]

f2_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-GCN': bert,
    'PT-BERT-GCN': bert_pt,
    'ROBERTA-GCN':roberta,
    'PT-ROBERTA-GCN': roberta_pt})

##------------------------------------------------------------------------------------------------------------


f, (ax) = plt.subplots(nrows=1, ncols=2, figsize=(24, 10))
# f.set_ylim([70,95])
# print(ax)
# for each in range(2):
#     ax[each].set(ylim=(75, 91))
ax[0].set(ylim=(35, 65))
ax[1].set(ylim=(0.35, 0.7))
# ax.grid(True)
# sns.set_style("darkgrid")
mark = ['o','s','D','*']
g1 = sns.pointplot(x='Window Size', y='F1-Score', hue='Models', 
              data=pd.melt(f1_data, ['Window Size'],var_name="Models",value_name="F1-Score"),ax=ax[0],markers=mark)
g2 = sns.pointplot(x='Window Size', y='AUC', hue='Models', 
              data=pd.melt(f2_data, ['Window Size'],var_name="Models",value_name="AUC"),ax=ax[1],markers=mark) #markers = ['s','D','d','+','o']
# g1.legend_.remove()
# g2.legend_.remove()
# g3.legend_.remove()

handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

ylabels = ["F-Measure", "AUC"]
for e in range(2):
    ax[e].set_xlabel("Window Size",fontsize=40)
    ax[e].set_ylabel(ylabels[e],fontsize=40)
#     leg = ax[e].legend(markerscale=2.0)
    ax[e].legend().get_frame().set_linewidth(7)
    ax[e].legend().get_frame().set_edgecolor('black')
    for axis in ['top','bottom','left','right']:
        ax[e].spines[axis].set_linewidth(1)
        ax[e].spines[axis].set_color('black')
    
#x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=5.0,bbox_to_anchor=(0.06, 0.91, 0.78, .05), loc='right',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
f.savefig('COR_ScratchvsPT_rev.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %% [markdown]
# ### MAM

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# sns.set(rc={'figure.figsize':(30,40)})
sns.set(font_scale = 2.5,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

x = ['W-all','W5','W4','W3'][::-1]


bert=[0.41316,0.55493,0.574963,0.637555]
bert_pt = [0.413207,0.559704,0.588469,0.656601]
roberta=[0.461861,0.487585,0.576371,0.657343]
roberta_pt=[0.285101,0.551835,0.530594,0.630716]





bert = [round(100*each,2) for each in bert][::-1]
bert_pt = [round(100*each,2) for each in bert_pt][::-1]
roberta = [round(100*each,2) for each in roberta][::-1]
roberta_pt  = [round(100*each,2) for each in roberta_pt][::-1]

f1_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-GCN': bert,
    'PT-BERT-GCN': bert_pt,
    'ROBERTA-GCN':roberta,
    'PT-ROBERTA-GCN': roberta_pt})
##------------------------------------------------------------------------------------------------------------


bert=[0.644646,0.613725,0.636194,0.688787]
bert_pt = [0.5913,0.606185,0.62199,0.65283]
roberta=[0.550651,0.651649,0.609912,0.680247]
roberta_pt=[0.631771,0.602518,0.570328,0.635279]



bert = [round(each,2) for each in bert][::-1]
bert_pt = [round(each,2) for each in bert_pt][::-1]
roberta = [round(each,2) for each in roberta][::-1]
roberta_pt  = [round(each,2) for each in roberta_pt][::-1]

f2_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-GCN': bert,
    'PT-BERT-GCN': bert_pt,
    'ROBERTA-GCN':roberta,
    'PT-ROBERTA-GCN': roberta_pt})

##------------------------------------------------------------------------------------------------------------


f, (ax) = plt.subplots(nrows=1, ncols=2, figsize=(24, 10))
# f.set_ylim([70,95])
# print(ax)
# for each in range(2):
#     ax[each].set(ylim=(75, 91))
ax[0].set(ylim=(25, 70))
ax[1].set(ylim=(0.4, 0.7))
# ax.grid(True)
# sns.set_style("darkgrid")
mark = ['o','s','D','*']
g1 = sns.pointplot(x='Window Size', y='F1-Score', hue='Models', 
              data=pd.melt(f1_data, ['Window Size'],var_name="Models",value_name="F1-Score"),ax=ax[0],markers=mark)
g2 = sns.pointplot(x='Window Size', y='AUC', hue='Models', 
              data=pd.melt(f2_data, ['Window Size'],var_name="Models",value_name="AUC"),ax=ax[1],markers=mark) #markers = ['s','D','d','+','o']
# g1.legend_.remove()
# g2.legend_.remove()
# g3.legend_.remove()

handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

ylabels = ["F-Measure", "AUC"]
for e in range(2):
    ax[e].set_xlabel("Window Size",fontsize=40)
    ax[e].set_ylabel(ylabels[e],fontsize=40)
#     leg = ax[e].legend(markerscale=2.0)
    ax[e].legend().get_frame().set_linewidth(7)
    ax[e].legend().get_frame().set_edgecolor('black')
    for axis in ['top','bottom','left','right']:
        ax[e].spines[axis].set_linewidth(1)
        ax[e].spines[axis].set_color('black')
    
#x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=5.0,bbox_to_anchor=(0.06, 0.91, 0.78, .05), loc='right',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
f.savefig('MAM_ScratchvsPT_rev.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %%
# CTF writeup
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# sns.set(rc={'figure.figsize':(30,40)})
sns.set(font_scale = 2.5,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

x = ['W-all','W5','W4','W3'][::-1]


bert=[0.368359,0.578733,0.625412,0.692613]
bert_pt = [0.324931,0.542445,0.596831,0.655607]
roberta=[0.295724,0.58663,0.628875,0.690411]
roberta_pt=[0.340781,0.573087,0.617586,0.677464]





bert = [round(100*each,2) for each in bert][::-1]
bert_pt = [round(100*each,2) for each in bert_pt][::-1]
roberta = [round(100*each,2) for each in roberta][::-1]
roberta_pt  = [round(100*each,2) for each in roberta_pt][::-1]

f1_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-GCN': bert,
    'PT-BERT-GCN': bert_pt,
    'ROBERTA-GCN':roberta,
    'PT-ROBERTA-GCN': roberta_pt})
##------------------------------------------------------------------------------------------------------------


bert=[0.475222,0.612222,0.654235,0.70751]
bert_pt = [0.559011,0.582933,0.608685,0.665797]
roberta=[0.391706,0.615013,0.652014,0.722126]
roberta_pt=[0.511957,0.599376,0.633151,0.681354]



bert = [round(each,2) for each in bert][::-1]
bert_pt = [round(each,2) for each in bert_pt][::-1]
roberta = [round(each,2) for each in roberta][::-1]
roberta_pt  = [round(each,2) for each in roberta_pt][::-1]

f2_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-GCN': bert,
    'PT-BERT-GCN': bert_pt,
    'ROBERTA-GCN':roberta,
    'PT-ROBERTA-GCN': roberta_pt})

##------------------------------------------------------------------------------------------------------------


f, (ax) = plt.subplots(nrows=1, ncols=2, figsize=(24, 10))
# f.set_ylim([70,95])
# print(ax)
# for each in range(2):
#     ax[each].set(ylim=(75, 91))
ax[0].set(ylim=(25, 70))
ax[1].set(ylim=(0.3, 0.75))
# ax.grid(True)
# sns.set_style("darkgrid")
mark = ['o','s','D','*']
g1 = sns.pointplot(x='Window Size', y='F1-Score', hue='Models', 
              data=pd.melt(f1_data, ['Window Size'],var_name="Models",value_name="F1-Score"),ax=ax[0],markers=mark)
g2 = sns.pointplot(x='Window Size', y='AUC', hue='Models', 
              data=pd.melt(f2_data, ['Window Size'],var_name="Models",value_name="AUC"),ax=ax[1],markers=mark) #markers = ['s','D','d','+','o']
# g1.legend_.remove()
# g2.legend_.remove()
# g3.legend_.remove()

handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

ylabels = ["F-Measure", "AUC"]
for e in range(2):
    ax[e].set_xlabel("Window Size",fontsize=40)
    ax[e].set_ylabel(ylabels[e],fontsize=40)
#     leg = ax[e].legend(markerscale=2.0)
    ax[e].legend().get_frame().set_linewidth(7)
    ax[e].legend().get_frame().set_edgecolor('black')
    for axis in ['top','bottom','left','right']:
        ax[e].spines[axis].set_linewidth(1)
        ax[e].spines[axis].set_color('black')
    
#x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=5.0,bbox_to_anchor=(0.06, 0.91, 0.78, .05), loc='right',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
f.savefig('CTF_ScratchvsPT_rev.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %% [markdown]
# ### LM-LARGE vs LM-BASE

# %%
# COR writeup
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# sns.set(rc={'figure.figsize':(30,40)})
sns.set(font_scale = 2.5,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

x = ['W-all','W5','W4','W3'][::-1]





bert=[0.435233,0.527967,0.550633,0.58132]
bert_pt = [0.365843,0.526038,0.563871,0.595078]
roberta=[0.402913,0.513455,0.561717,0.614458]
roberta_pt=[0.442221,0.541899,0.579752,0.629359]


bert = [round(100*each,2) for each in bert][::-1]
bert_pt = [round(100*each,2) for each in bert_pt][::-1]
roberta = [round(100*each,2) for each in roberta][::-1]
roberta_pt  = [round(100*each,2) for each in roberta_pt][::-1]

f1_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-Base': bert,
    'BERT-Large': bert_pt,
    'ROBERTA-Base':roberta,
    'ROBERTA-Large': roberta_pt})
##------------------------------------------------------------------------------------------------------------






bert=[0.558026,0.527397,0.558108,0.631217]
bert_pt = [0.401978,0.49942,0.54409,0.603275]
roberta=[0.505591,0.514585,0.560865,0.623316]
roberta_pt=[0.396277,0.53661,0.601245,0.645562]

bert = [round(each,2) for each in bert][::-1]
bert_pt = [round(each,2) for each in bert_pt][::-1]
roberta = [round(each,2) for each in roberta][::-1]
roberta_pt  = [round(each,2) for each in roberta_pt][::-1]

f2_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-Base': bert,
    'BERT-Large': bert_pt,
    'ROBERTA-Base':roberta,
    'ROBERTA-Large': roberta_pt})

##------------------------------------------------------------------------------------------------------------


f, (ax) = plt.subplots(nrows=1, ncols=2, figsize=(24, 10))
# f.set_ylim([70,95])
# print(ax)
# for each in range(2):
#     ax[each].set(ylim=(75, 91))
ax[0].set(ylim=(30, 65))
ax[1].set(ylim=(0.3, 0.7))
# ax.grid(True)
# sns.set_style("darkgrid")
mark = ['o','s','D','*']
g1 = sns.pointplot(x='Window Size', y='F1-Score', hue='Models', 
              data=pd.melt(f1_data, ['Window Size'],var_name="Models",value_name="F1-Score"),ax=ax[0],markers=mark)
g2 = sns.pointplot(x='Window Size', y='AUC', hue='Models', 
              data=pd.melt(f2_data, ['Window Size'],var_name="Models",value_name="AUC"),ax=ax[1],markers=mark) #markers = ['s','D','d','+','o']
# g1.legend_.remove()
# g2.legend_.remove()
# g3.legend_.remove()

handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

ylabels = ["F-Measure", "AUC"]
for e in range(2):
    ax[e].set_xlabel("Window Size",fontsize=40)
    ax[e].set_ylabel(ylabels[e],fontsize=40)
#     leg = ax[e].legend(markerscale=2.0)
    ax[e].legend().get_frame().set_linewidth(7)
    ax[e].legend().get_frame().set_edgecolor('black')
    for axis in ['top','bottom','left','right']:
        ax[e].spines[axis].set_linewidth(1)
        ax[e].spines[axis].set_color('black')
    
#x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=5.0,bbox_to_anchor=(0.06, 0.91, 0.78, .05), loc='right',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
f.savefig('COR_BasevsLarge_rev.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %%
# MAM writeup
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# sns.set(rc={'figure.figsize':(30,40)})
sns.set(font_scale = 2.5,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

x = ['W-all','W5','W4','W3'][::-1]





bert=[0.41316,0.55493,0.574963,0.637555]
bert_pt = [0.253372,0.487585,0.527582,0.617067]
roberta=[0.285101,0.551835,0.576371,0.657343]
roberta_pt=[0.253372,0.487585,0.536479,0.621359]


bert = [round(100*each,2) for each in bert][::-1]
bert_pt = [round(100*each,2) for each in bert_pt][::-1]
roberta = [round(100*each,2) for each in roberta][::-1]
roberta_pt  = [round(100*each,2) for each in roberta_pt][::-1]

f1_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-Base': bert,
    'BERT-Large': bert_pt,
    'ROBERTA-Base':roberta,
    'ROBERTA-Large': roberta_pt})
##------------------------------------------------------------------------------------------------------------


bert=[0.644646,0.613725,0.636194,0.688787]
bert_pt = [0.336187,0.477891,0.536901,0.553372]
roberta=[0.671771,0.602518,0.609912,0.680247]
roberta_pt=[0.352887,0.651649,0.515423,0.585837]

bert = [round(each,2) for each in bert][::-1]
bert_pt = [round(each,2) for each in bert_pt][::-1]
roberta = [round(each,2) for each in roberta][::-1]
roberta_pt  = [round(each,2) for each in roberta_pt][::-1]

f2_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-Base': bert,
    'BERT-Large': bert_pt,
    'ROBERTA-Base':roberta,
    'ROBERTA-Large': roberta_pt})

##------------------------------------------------------------------------------------------------------------


f, (ax) = plt.subplots(nrows=1, ncols=2, figsize=(24, 10))
# f.set_ylim([70,95])
# print(ax)
# for each in range(2):
#     ax[each].set(ylim=(75, 91))
ax[0].set(ylim=(22, 70))
ax[1].set(ylim=(0.30, 0.7))
# ax.grid(True)
# sns.set_style("darkgrid")
mark = ['o','s','D','*']
g1 = sns.pointplot(x='Window Size', y='F1-Score', hue='Models', 
              data=pd.melt(f1_data, ['Window Size'],var_name="Models",value_name="F1-Score"),ax=ax[0],markers=mark)
g2 = sns.pointplot(x='Window Size', y='AUC', hue='Models', 
              data=pd.melt(f2_data, ['Window Size'],var_name="Models",value_name="AUC"),ax=ax[1],markers=mark) #markers = ['s','D','d','+','o']
# g1.legend_.remove()
# g2.legend_.remove()
# g3.legend_.remove()

handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

ylabels = ["F-Measure", "AUC"]
for e in range(2):
    ax[e].set_xlabel("Window Size",fontsize=40)
    ax[e].set_ylabel(ylabels[e],fontsize=40)
#     leg = ax[e].legend(markerscale=2.0)
    ax[e].legend().get_frame().set_linewidth(7)
    ax[e].legend().get_frame().set_edgecolor('black')
    for axis in ['top','bottom','left','right']:
        ax[e].spines[axis].set_linewidth(1)
        ax[e].spines[axis].set_color('black')
    
#x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=5.0,bbox_to_anchor=(0.06, 0.91, 0.78, .05), loc='right',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
f.savefig('MAM_BasevsLarge_rev.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %%
# CTF writeup
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# sns.set(rc={'figure.figsize':(30,40)})
sns.set(font_scale = 2.5,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

x = ['W-all','W5','W4','W3'][::-1]


bert=[0.324931,0.578733,0.625412,0.692613]
bert_pt = [0.21875,0.500326,0.585594,0.638743]
roberta=[0.340781,0.58663,0.628875,0.690411]
roberta_pt=[0.227489,0.386927,0.561031,0.552481]


bert = [round(100*each,2) for each in bert][::-1]
bert_pt = [round(100*each,2) for each in bert_pt][::-1]
roberta = [round(100*each,2) for each in roberta][::-1]
roberta_pt  = [round(100*each,2) for each in roberta_pt][::-1]

f1_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-Base': bert,
    'BERT-Large': bert_pt,
    'ROBERTA-Base':roberta,
    'ROBERTA-Large': roberta_pt})
##------------------------------------------------------------------------------------------------------------





bert=[0.559011,0.612222,0.654235,0.70751]
bert_pt = [0.268722,0.51353,0.579401,0.61749]
roberta=[0.511957,0.615013,0.652014,0.722126]
roberta_pt=[0.283893,0.370315,0.567257,0.601899]

bert = [round(each,2) for each in bert][::-1]
bert_pt = [round(each,2) for each in bert_pt][::-1]
roberta = [round(each,2) for each in roberta][::-1]
roberta_pt  = [round(each,2) for each in roberta_pt][::-1]

f2_data = pd.DataFrame({
    'Window Size': x, 
    'BERT-Base': bert,
    'BERT-Large': bert_pt,
    'ROBERTA-Base':roberta,
    'ROBERTA-Large': roberta_pt})

##------------------------------------------------------------------------------------------------------------


f, (ax) = plt.subplots(nrows=1, ncols=2, figsize=(24, 10))
# f.set_ylim([70,95])
# print(ax)
# for each in range(2):
#     ax[each].set(ylim=(75, 91))
ax[0].set(ylim=(10, 75))
ax[1].set(ylim=(0.2, 0.75))
# ax[1].tick_params(axis='both', which='minor', labelsize=8)
# ax.grid(True)
# sns.set_style("darkgrid")

mark = ['o','s','D','*']
g1 = sns.pointplot(x='Window Size', y='F1-Score', hue='Models', 
              data=pd.melt(f1_data, ['Window Size'],var_name="Models",value_name="F1-Score"),ax=ax[0],markers=mark)
g2 = sns.pointplot(x='Window Size', y='AUC', hue='Models', 
              data=pd.melt(f2_data, ['Window Size'],var_name="Models",value_name="AUC"),ax=ax[1],markers=mark) #markers = ['s','D','d','+','o']
# g1.legend_.remove()
# g2.legend_.remove()
# g3.legend_.remove()

handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

ylabels = ["F-Measure", "AUC"]
for e in range(2):
    ax[e].set_xlabel("Window Size",fontsize=40)
    ax[e].set_ylabel(ylabels[e],fontsize=40)
#     leg = ax[e].legend(markerscale=2.0)
    ax[e].legend().get_frame().set_linewidth(7)
    ax[e].legend().get_frame().set_edgecolor('black')
    for axis in ['top','bottom','left','right']:
        ax[e].spines[axis].set_linewidth(1)
        ax[e].spines[axis].set_color('black')
    
#x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=5.0,bbox_to_anchor=(0.06, 0.91, 0.78, .05), loc='right',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
f.savefig('CTF_BasevsLarge_rev.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %% [markdown]
# ### Effect of GNN Layers

# %%
# # CTF writeup F1
# %matplotlib inline
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
# # sns.set(rc={'figure.figsize':(30,40)})
# sns.set(font_scale = 3,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

# x = ['L0','L1','L2']




# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f1_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat})
# ##------------------------------------------------------------------------------------------------------------




# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f2_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat
# })

# ##------------------------------------------------------------------------------------------------------------




# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f3_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat
# })

# ##------------------------------------------------------------------------------------------------------------




# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f4_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat
# })

# ##------------------------------------------------------------------------------------------------------------


# f, (ax) = plt.subplots(nrows=1, ncols=4, figsize=(34, 7))
# # f.set_ylim([70,95])
# # print(ax)
# # for each in range(2):
# #     ax[each].set(ylim=(75, 91))
# ax[0].set(ylim=(20, 36))
# ax[1].set(ylim=(28, 58))
# ax[2].set(ylim=(40, 64))
# ax[3].set(ylim=(40, 68))
# # ax[1].tick_params(axis='both', which='minor', labelsize=8)
# # ax.grid(True)
# # sns.set_style("darkgrid")

# g1 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f1_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[0],markers="o")
# g2 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f2_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[1],markers="o") #markers = ['s','D','d','+','o']  
# g3 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f3_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[2],markers="o")
# g4 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f4_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[3],markers="o")

# handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

# # ylabels = ["F-Measure"]
# for e in range(4):
#     ax[e].set_xlabel("GNN Layers",fontsize=40)
# #     ax[e].set_ylabel(ylabels[e],fontsize=40)
# #     leg = ax[e].legend(markerscale=2.0)
#     ax[e].legend().get_frame().set_linewidth(7)
#     ax[e].legend().get_frame().set_edgecolor('black')
#     for axis in ['top','bottom','left','right']:
#         ax[e].spines[axis].set_linewidth(1)
#         ax[e].spines[axis].set_color('black')
        

# ax[0].set_xlabel('GNN Layers (W-all)')
# ax[1].set_xlabel('GNN Layers (W5)')
# ax[2].set_xlabel('GNN Layers (W4)')
# ax[3].set_xlabel('GNN Layers (W3)')

# ax[1].set_ylabel('')
# ax[2].set_ylabel('')
# ax[3].set_ylabel('')
# ax[0].get_legend().remove()
# ax[1].get_legend().remove()
# ax[2].get_legend().remove()
# ax[3].get_legend().remove()

    
# #x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=2.5,bbox_to_anchor=(0.06, 0.99, 0.78, .05), loc='right',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
# f.savefig('CTF_GNNLayers_F1.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %%
# CTF writeup AUC
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# sns.set(rc={'figure.figsize':(30,40)})
sns.set(font_scale = 3,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

x = ['L0','L1','L2']

bgcn=[0.165387,0.559011,0.475222]
rgcn = [0.178762,0.511957,0.33707]
bgat=[0.165387,0.232087,0.179868]
rgat=[0.178762,0.224675,0.193221]


bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]


f1_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat})
##------------------------------------------------------------------------------------------------------------


bgcn=[0.333827,0.612222,0.582933]
rgcn = [0.366816,0.615013,0.563345]
bgat=[0.333827,0.447273,0.349374]
rgat=[0.366816,0.467922,0.372987]



bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]

f2_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat
})

##------------------------------------------------------------------------------------------------------------
bgcn=[0.38518,0.654235,0.59963]
rgcn = [0.412918,0.652014,0.596281]
bgat=[0.38518,0.487147,0.369416]
rgat=[0.412918,0.50234,0.436596]


bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]


f3_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat
})

##------------------------------------------------------------------------------------------------------------



bgcn=[0.478333,0.70751,0.646744]
rgcn = [0.483382,0.722126,0.66634]
bgat=[0.478333,0.558487,0.440132]
rgat=[0.483382,0.56919,0.517026]


bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]

f4_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat
})

##------------------------------------------------------------------------------------------------------------


f, (ax) = plt.subplots(nrows=1, ncols=4, figsize=(34, 7))
# f.set_ylim([70,95])
# print(ax)
# for each in range(2):
#     ax[each].set(ylim=(75, 91))
ax[0].set(ylim=(0.1, 0.6))
ax[1].set(ylim=(0.3, 0.65))
ax[2].set(ylim=(0.3, 0.7))
ax[3].set(ylim=(0.4, 0.8))
# ax[1].tick_params(axis='both', which='minor', labelsize=8)
# ax.grid(True)
# sns.set_style("darkgrid")
mark = ['o','s','D','*']
g1 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f1_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[0],markers=mark)
g2 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f2_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[1],markers=mark) #markers = ['s','D','d','+','o']  
g3 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f3_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[2],markers=mark)
g4 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f4_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[3],markers=mark)

handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

# ylabels = ["F-Measure"]
for e in range(2):
    ax[e].set_xlabel("GNN Layers",fontsize=40)
#     ax[e].set_ylabel(ylabels[e],fontsize=40)
#     leg = ax[e].legend(markerscale=2.0)
    ax[e].legend().get_frame().set_linewidth(7)
    ax[e].legend().get_frame().set_edgecolor('black')
    for axis in ['top','bottom','left','right']:
        ax[e].spines[axis].set_linewidth(1)
        ax[e].spines[axis].set_color('black')
        

ax[0].set_xlabel('W-all')
ax[1].set_xlabel('W5')
ax[2].set_xlabel('W4')
ax[3].set_xlabel('W3')

ax[0].set_ylabel('AUC (CTFW)')
ax[1].set_ylabel('')
ax[2].set_ylabel('')
ax[3].set_ylabel('')
ax[0].get_legend().remove()
ax[1].get_legend().remove()
ax[2].get_legend().remove()
ax[3].get_legend().remove()

    
#x0,y0, width, height
lgd = f.legend(handles, labels,markerscale=1.5,bbox_to_anchor=(0.06, 0.99, 0.78, .05), loc='right',
           ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
f.savefig('CTF_GNNLayers_AUC.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %% [markdown]
# ### MAM

# %%
# # MAM writeup F1
# %matplotlib inline
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
# # sns.set(rc={'figure.figsize':(30,40)})
# sns.set(font_scale = 3,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

# x = ['L0','L1','L2']







# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f1_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat
# })

# ##------------------------------------------------------------------------------------------------------------




# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f2_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat})
# ##------------------------------------------------------------------------------------------------------------




# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f3_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat
# })

# ##------------------------------------------------------------------------------------------------------------






# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f4_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat
# })

# ##------------------------------------------------------------------------------------------------------------


# f, (ax) = plt.subplots(nrows=1, ncols=4, figsize=(34, 7))
# # f.set_ylim([70,95])
# # print(ax)
# # for each in range(2):
# #     ax[each].set(ylim=(75, 91))
# ax[0].set(ylim=(24, 42))
# ax[1].set(ylim=(35, 64))
# ax[2].set(ylim=(35, 68))
# ax[3].set(ylim=(40, 75))
# # ax[1].tick_params(axis='both', which='minor', labelsize=8)
# # ax.grid(True)
# # sns.set_style("darkgrid")
# g1 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f1_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[0],markers="o")
# g2 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f2_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[1],markers="o") #markers = ['s','D','d','+','o']  
# g3 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f3_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[2],markers="o")
# g4 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f4_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[3],markers="o")

# handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

# # ylabels = ["F-Measure"]
# for e in range(4):
#     ax[e].set_xlabel("GNN Layers",fontsize=40)
# #     ax[e].set_ylabel(ylabels[e],fontsize=40)
# #     leg = ax[e].legend(markerscale=2.0)
#     ax[e].legend().get_frame().set_linewidth(7)
#     ax[e].legend().get_frame().set_edgecolor('black')
#     for axis in ['top','bottom','left','right']:
#         ax[e].spines[axis].set_linewidth(1)
#         ax[e].spines[axis].set_color('black')
        

# ax[0].set_xlabel('GNN Layers (W-all)')
# ax[1].set_xlabel('GNN Layers (W5)')
# ax[2].set_xlabel('GNN Layers (W4)')
# ax[3].set_xlabel('GNN Layers (W3)')

# ax[1].set_ylabel('')
# ax[2].set_ylabel('')
# ax[3].set_ylabel('')
# ax[0].get_legend().remove()
# ax[1].get_legend().remove()
# ax[2].get_legend().remove()
# ax[3].get_legend().remove()

    
# #x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=2.5,bbox_to_anchor=(0.06, 0.99, 0.78, .05), loc='right',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
# f.savefig('MAM_GNNLayers_F1.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %%
# MAM writeup AUC
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# sns.set(rc={'figure.figsize':(30,40)})
sns.set(font_scale = 3,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

x = ['L0','L1','L2']


bgcn=[0.156822,0.644646,0.567221]
rgcn = [0.152378,0.664577,0.671771]
bgat=[0.156822,0.274849,0.149629]
rgat=[0.152378,0.27767,0.178493]


bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]


f1_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat})
##------------------------------------------------------------------------------------------------------------




bgcn=[0.373149,0.613725,0.523966]
rgcn = [0.330313,0.651649,0.511533]
bgat=[0.373149,0.333279,0.326104]
rgat=[0.330313,0.32519,0.338126]


bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]

f2_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat
})

##------------------------------------------------------------------------------------------------------------


bgcn=[0.405578,0.636194,0.571874]
rgcn = [0.371348,0.609912,0.550495]
bgat=[0.405578,0.360137,0.368253]
rgat=[0.371348,0.366109,0.370806]

bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]


f3_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat
})

##------------------------------------------------------------------------------------------------------------

bgcn=[0.455889,0.688787,0.61339]
rgcn = [0.459542,0.635279,0.606562]
bgat=[0.455889,0.466798,0.45068]
rgat=[0.459542,0.458502,0.445544]

bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]

f4_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat
})

##------------------------------------------------------------------------------------------------------------


f, (ax) = plt.subplots(nrows=1, ncols=4, figsize=(34, 7))
# f.set_ylim([70,95])
# print(ax)
# for each in range(2):
#     ax[each].set(ylim=(75, 91))
ax[0].set(ylim=(0.1, 0.7))
ax[1].set(ylim=(0.30, 0.7))
ax[2].set(ylim=(0.30, 0.7))
ax[3].set(ylim=(0.40, 0.7))
# ax[1].tick_params(axis='both', which='minor', labelsize=8)
# ax.grid(True)
# sns.set_style("darkgrid")
mark = ['o','s','D','*']
g1 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f1_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[0],markers=mark)
g2 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f2_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[1],markers=mark) #markers = ['s','D','d','+','o']  
g3 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f3_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[2],markers=mark)
g4 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f4_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[3],markers=mark)

handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

# ylabels = ["F-Measure"]
for e in range(2):
    ax[e].set_xlabel("GNN Layers",fontsize=40)
#     ax[e].set_ylabel(ylabels[e],fontsize=40)
#     leg = ax[e].legend(markerscale=2.0)
    ax[e].legend().get_frame().set_linewidth(7)
    ax[e].legend().get_frame().set_edgecolor('black')
    for axis in ['top','bottom','left','right']:
        ax[e].spines[axis].set_linewidth(1)
        ax[e].spines[axis].set_color('black')
        

ax[0].set_xlabel('W-all')
ax[1].set_xlabel('W5')
ax[2].set_xlabel('W4')
ax[3].set_xlabel('W3')


ax[0].set_ylabel('AUC (MAM)')
ax[1].set_ylabel('')
ax[2].set_ylabel('')
ax[3].set_ylabel('')
ax[0].get_legend().remove()
ax[1].get_legend().remove()
ax[2].get_legend().remove()
ax[3].get_legend().remove()

    
#x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=2.5,bbox_to_anchor=(0.06, 0.91, 0.78, .05), loc='right',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
f.savefig('MAM_GNNLayers_AUC.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %% [markdown]
# ### COR

# %%
# # COR writeup F1
# %matplotlib inline
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
# # sns.set(rc={'figure.figsize':(30,40)})
# sns.set(font_scale = 3,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

# x = ['L0','L1','L2']


# bgcn=[0.334331,0.503123,0.430037]
# rgcn = [0.390869,0.484787,0.439458]
# bgat=[0.334331,0.432877,0.352609]
# rgat=[0.390869,0.456288,0.360759]



# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f1_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat
# })

# ##------------------------------------------------------------------------------------------------------------

# bgcn=[0.464475,0.625382,0.580721]
# rgcn = [0.507042,0.617549,0.602532]
# bgat=[0.464475,0.581509,0.479042]
# rgat=[0.507042,0.564226,0.463741]


# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f2_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat})
# ##------------------------------------------------------------------------------------------------------------


# bgcn=[0.512027,0.676495,0.613077]
# rgcn = [0.532164,0.680982,0.641942]
# bgat=[0.512027,0.596424,0.51784]
# rgat=[0.516129,0.599872,0.512643]

# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f3_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat
# })

# ##------------------------------------------------------------------------------------------------------------


# bgcn=[0.593364,0.733756,0.662745]
# rgcn = [0.588317,0.710253,0.685552]
# bgat=[0.593364,0.683064,0.588032]
# rgat=[0.588317,0.673514,0.588883]



# bgcn = [round(100*each,2) for each in bgcn]
# rgcn = [round(100*each,2) for each in rgcn]
# bgat = [round(100*each,2) for each in bgat]
# rgat  = [round(100*each,2) for each in rgat]

# f4_data = pd.DataFrame({
#     'GNN Layers': x, 
#     'BERT-GCN': bgcn,
#     'ROBERTA-GCN': rgcn,
#     'BERT-GAT':bgat,
#     'ROBERTA-GAT': rgat
# })

# ##------------------------------------------------------------------------------------------------------------


# f, (ax) = plt.subplots(nrows=1, ncols=4, figsize=(34, 7))
# # f.set_ylim([70,95])
# # print(ax)
# # for each in range(2):
# #     ax[each].set(ylim=(75, 91))
# ax[0].set(ylim=(32, 52))
# ax[1].set(ylim=(45, 64))
# ax[2].set(ylim=(50, 70))
# ax[3].set(ylim=(56, 75))
# # ax[1].tick_params(axis='both', which='minor', labelsize=8)
# # ax.grid(True)
# # sns.set_style("darkgrid")
# mark = ['o','s','D','*']
# g1 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f1_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[0],markers=mark)
# g2 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f2_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[1],markers=mark) #markers = ['s','D','d','+','o']  
# g3 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f3_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[2],markers=mark)
# g4 = sns.pointplot(x='GNN Layers', y='F1-Score', hue='Models', 
#               data=pd.melt(f4_data, ['GNN Layers'],var_name="Models",value_name="F1-Score"),ax=ax[3],markers=mark)

# handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

# # ylabels = ["F-Measure"]
# for e in range(4):
#     ax[e].set_xlabel("GNN Layers",fontsize=40)
# #     ax[e].set_ylabel(ylabels[e],fontsize=40)
# #     leg = ax[e].legend(markerscale=2.0)
#     ax[e].legend().get_frame().set_linewidth(7)
#     ax[e].legend().get_frame().set_edgecolor('black')
#     for axis in ['top','bottom','left','right']:
#         ax[e].spines[axis].set_linewidth(1)
#         ax[e].spines[axis].set_color('black')
        

# ax[0].set_xlabel('GNN Layers (W-all)')
# ax[1].set_xlabel('GNN Layers (W5)')
# ax[2].set_xlabel('GNN Layers (W4)')
# ax[3].set_xlabel('GNN Layers (W3)')

# ax[1].set_ylabel('')
# ax[2].set_ylabel('')
# ax[3].set_ylabel('')
# ax[0].get_legend().remove()
# ax[1].get_legend().remove()
# ax[2].get_legend().remove()
# ax[3].get_legend().remove()

    
# #x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=2.5,bbox_to_anchor=(0.06, 0.99, 0.78, .05), loc='right',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
# f.savefig('COR_GNNLayers_F1.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %%
# COR writeup AUC
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# sns.set(rc={'figure.figsize':(30,40)})
sns.set(font_scale = 3,style="whitegrid",rc={"lines.linewidth": 3,"lines.color":'b',"axes.linewidth":5})

x = ['L0','L1','L2']

bgcn=[0.243954,0.558026,0.477613]
rgcn = [0.27774,0.460651,0.505591]
bgat=[0.243954,0.257588,0.287808]
rgat=[0.27774,0.270043,0.278412]





bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]


f1_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat})
##------------------------------------------------------------------------------------------------------------


bgcn=[0.497593,0.631217,0.548183]
rgcn = [0.516039,0.645562,0.563548]
bgat=[0.497593,0.455293,0.432521]
rgat=[0.516039,0.435842,0.41969]


bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]

f2_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat
})

##------------------------------------------------------------------------------------------------------------

bgcn=[0.428376,0.551405,0.537279]
rgcn = [0.44325,0.601245,0.512959]
bgat=[0.428376,0.38706,0.353369]
rgat=[0.44325,0.362582,0.367033]

bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]


f3_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat
})

##------------------------------------------------------------------------------------------------------------

bgcn=[0.497593,0.631217,0.548183]
rgcn = [0.516039,0.645562,0.563548]
bgat=[0.497593,0.455293,0.432521]
rgat=[0.516039,0.435842,0.41969]




bgcn = [round(each,2) for each in bgcn]
rgcn = [round(each,2) for each in rgcn]
bgat = [round(each,2) for each in bgat]
rgat  = [round(each,2) for each in rgat]

f4_data = pd.DataFrame({
    'GNN Layers': x, 
    'BERT-GCN': bgcn,
    'ROBERTA-GCN': rgcn,
    'BERT-GAT':bgat,
    'ROBERTA-GAT': rgat
})

##------------------------------------------------------------------------------------------------------------


f, (ax) = plt.subplots(nrows=1, ncols=4, figsize=(34, 7))
# f.set(ylim=([0.2,0.9]))
# print(ax)
# for each in range(2):
#     ax[each].set(ylim=(75, 91))
ax[0].set(ylim=(0.20, 0.6))
ax[1].set(ylim=(0.40, 0.7))
ax[2].set(ylim=(0.30, 0.7))
ax[3].set(ylim=(0.40, 0.7))

# ax[0].get_shared_y_axes().join(ax[0], ax[1])

# ax[1].tick_params(axis='both', which='minor', labelsize=8)
# ax.grid(True)
# sns.set_style("darkgrid")
mark = ['o','s','D','*']
g1 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f1_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[0],markers=mark)
g2 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f2_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[1],markers=mark) #markers = ['s','D','d','+','o']  
g3 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f3_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[2],markers=mark)
g4 = sns.pointplot(x='GNN Layers', y='AUC', hue='Models', 
              data=pd.melt(f4_data, ['GNN Layers'],var_name="Models",value_name="AUC"),ax=ax[3],markers=mark)

handles, labels = ax[1].get_legend_handles_labels()#Common legend for all subplot

# ylabels = ["F-Measure"]
for e in range(2):
    ax[e].set_xlabel("GNN Layers",fontsize=40)
#     ax[e].set_ylabel(ylabels[e],fontsize=40)
#     leg = ax[e].legend(markerscale=2.0)
    ax[e].legend().get_frame().set_linewidth(7)
    ax[e].legend().get_frame().set_edgecolor('black')
    for axis in ['top','bottom','left','right']:
        ax[e].spines[axis].set_linewidth(1)
        ax[e].spines[axis].set_color('black')
        

ax[0].set_xlabel('W-all')
ax[1].set_xlabel('W5')
ax[2].set_xlabel('W4')
ax[3].set_xlabel('W3')

ax[0].set_ylabel('AUC (COR)')
ax[1].set_ylabel('')
ax[2].set_ylabel('')
ax[3].set_ylabel('')
ax[0].get_legend().remove()
ax[1].get_legend().remove()
ax[2].get_legend().remove()
ax[3].get_legend().remove()

    
#x0,y0, width, height
# lgd = f.legend(handles, labels,markerscale=2.5,bbox_to_anchor=(0.06, 0.91, 0.78, .05), loc='right',
#            ncol=4 , mode="expand", borderaxespad=0.0) #Common legend for all subplot
f.savefig('COR_GNNLayers_AUC.png', bbox_extra_artists=(lgd,), bbox_inches='tight',dpi=300) # High resolution and also helps outside legend to not get cut off during saving

# %%
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Create a dataset with many short random walks
rs = np.random.RandomState(3)
pos = rs.randint(-1, 2, (12, 3)).cumsum(axis=1)
pos -= pos[:, 0, np.newaxis]
step = np.tile(range(3), 12)
walk = np.repeat(range(12), 3)
df = pd.DataFrame(np.c_[pos.flat, step, walk],
                  columns=["PRAUC", "GNN Layers", "walk"])

# Initialize a grid of plots with an Axes for each walk
grid = sns.FacetGrid(df, col="walk", hue="walk", palette="tab20c", col_wrap=4, height=1.5,sharey=False)

# Draw a horizontal line to show the starting point
grid.map(plt.axhline, y=20, ls=":", c=".5")

# Draw a line plot to show the trajectory of each random walk
grid.map(plt.plot, "GNN Layers", "PRAUC", marker="o")
# grid.map(plt.plot, "step", "position", marker="x")

# Adjust the tick positions and labels
grid.set(xticks=np.arange(3), yticks=[0,70], xlim=(20, 44), ylim=(1, 50))

# Adjust the arrangement of the plots
grid.fig.tight_layout(w_pad=0.5)

# %%
import numpy as np

t = np.arange(0.0, 2.0, 0.01)
t1 = np.arange(2.0, 4.0, 0.01)

s1 = np.sin(2 * np.pi * t)
s2 = np.exp(-t)
s3 = s1 * s2

fig, axs = plt.subplots(3, 2, sharex=True)
# Remove horizontal space between axes
fig.subplots_adjust(hspace=0)

# Plot each graph, and manually set the y tick values
axs[0].plot(t, s1)
axs[0].set_yticks(np.arange(-0.9, 1.0, 0.4))
axs[0].set_ylim(-1, 1)

axs[1].plot(t, s2)
axs[1].set_yticks(np.arange(0.1, 1.0, 0.2))
axs[1].set_ylim(0, 1)

axs[2].plot(t, s3)
axs[2].set_yticks(np.arange(-0.9, 1.0, 0.4))
axs[2].set_ylim(-1, 1)

axs[3].plot(t1, s1)
axs[3].set_yticks(np.arange(-0.9, 1.0, 0.4))
axs[3].set_ylim(-1, 1)

axs[4].plot(t1, s2)
axs[4].set_yticks(np.arange(0.1, 1.0, 0.2))
axs[4].set_ylim(0, 1)

axs[5].plot(t1, s3)
axs[5].set_yticks(np.arange(-0.9, 1.0, 0.4))
axs[5].set_ylim(-1, 1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-ebd76f870e1e> in <module>
#      13
#      14 # Plot each graph, and manually set the y tick values
# ---> 15 axs[0].plot(t, s1)
#      16 axs[0].set_yticks(np.arange(-0.9, 1.0, 0.4))
#      17 axs[0].set_ylim(-1, 1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'
