# %%
import pandas as pd

# %% [markdown]
# # 1. CSV to LIST

# %%
data = pd.read_csv("data/pandas_tutorial_read.csv",delimiter=";", names=['mydatetime','event','country','userid','source','topic'])

# %%
dataList = data.values.tolist()

# %%
len(dataList)
# Out:
# 1795

# %%
# 2. JSON to

# %%
pd.read_json('data/final9.json')
# Out:
#                                                                     dataset_reader  \
# attention                                                                      NaN
# batch_size                                                                     NaN
# beam_size                                                                      NaN
# cuda_device                                                                    NaN
# encoder                                                                        NaN
# learning_rate_scheduler                                                        NaN
# max_decoding_steps                                                             NaN
# num_epochs                                                                     NaN
# optimizer                                                                      NaN
# padding_noise                                                                  NaN
# should_log_learning_rate                                                       NaN
# should_log_parameter_statistics                                                NaN
# sorting_keys                                                                   NaN
# source_embedder                                                                NaN
# source_token_indexers            {'tokens': {'type': 'single_id', 'namespace': ...
# target_embedding_dim                                                           NaN
# target_namespace                                                     target_tokens
# type                                                               copynet_seq2seq
# validation_metric                                                              NaN
#
#                                                       iterator  \
# attention                                                  NaN
# batch_size                                                  32
# beam_size                                                  NaN
# cuda_device                                                NaN
# encoder                                                    NaN
# learning_rate_scheduler                                    NaN
# max_decoding_steps                                         NaN
# num_epochs                                                 NaN
# optimizer                                                  NaN
# padding_noise                                                0
# should_log_learning_rate                                   NaN
# should_log_parameter_statistics                            NaN
# sorting_keys                     [[source_tokens, num_tokens]]
# source_embedder                                            NaN
# source_token_indexers                                      NaN
# target_embedding_dim                                       NaN
# target_namespace                                           NaN
# type                                                    bucket
# validation_metric                                          NaN
#
#                                                                              model  \
# attention                        {'type': 'bilinear', 'vector_dim': 200, 'matri...
# batch_size                                                                     NaN
# beam_size                                                                        3
# cuda_device                                                                    NaN
# encoder                          {'type': 'gru', 'input_size': 1374, 'hidden_si...
# learning_rate_scheduler                                                        NaN
# max_decoding_steps                                                              20
# num_epochs                                                                     NaN
# optimizer                                                                      NaN
# padding_noise                                                                  NaN
# should_log_learning_rate                                                       NaN
# should_log_parameter_statistics                                                NaN
# sorting_keys                                                                   NaN
# source_embedder                  {'tokens': {'type': 'embedding', 'pretrained_f...
# source_token_indexers                                                          NaN
# target_embedding_dim                                                           100
# target_namespace                                                               NaN
# type                                                                   copynetObqa
# validation_metric                                                              NaN
#
#                                            train_data_path  \
# attention                        data/trainDataSeq2seq.tsv
# batch_size                       data/trainDataSeq2seq.tsv
# beam_size                        data/trainDataSeq2seq.tsv
# cuda_device                      data/trainDataSeq2seq.tsv
# encoder                          data/trainDataSeq2seq.tsv
# learning_rate_scheduler          data/trainDataSeq2seq.tsv
# max_decoding_steps               data/trainDataSeq2seq.tsv
# num_epochs                       data/trainDataSeq2seq.tsv
# optimizer                        data/trainDataSeq2seq.tsv
# padding_noise                    data/trainDataSeq2seq.tsv
# should_log_learning_rate         data/trainDataSeq2seq.tsv
# should_log_parameter_statistics  data/trainDataSeq2seq.tsv
# sorting_keys                     data/trainDataSeq2seq.tsv
# source_embedder                  data/trainDataSeq2seq.tsv
# source_token_indexers            data/trainDataSeq2seq.tsv
# target_embedding_dim             data/trainDataSeq2seq.tsv
# target_namespace                 data/trainDataSeq2seq.tsv
# type                             data/trainDataSeq2seq.tsv
# validation_metric                data/trainDataSeq2seq.tsv
#
#                                                                            trainer  \
# attention                                                                      NaN
# batch_size                                                                     NaN
# beam_size                                                                      NaN
# cuda_device                                                                      0
# encoder                                                                        NaN
# learning_rate_scheduler          {'type': 'cosine', 't_initial': 5, 't_mul': 1....
# max_decoding_steps                                                             NaN
# num_epochs                                                                     100
# optimizer                                               {'type': 'sgd', 'lr': 0.1}
# padding_noise                                                                  NaN
# should_log_learning_rate                                                      True
# should_log_parameter_statistics                                              False
# sorting_keys                                                                   NaN
# source_embedder                                                                NaN
# source_token_indexers                                                          NaN
# target_embedding_dim                                                           NaN
# target_namespace                                                               NaN
# type                                                                           NaN
# validation_metric                                            +overlap_based_metric
#
#                                     validation_data_path
# attention                        data/devDataSeq2seq.tsv
# batch_size                       data/devDataSeq2seq.tsv
# beam_size                        data/devDataSeq2seq.tsv
# cuda_device                      data/devDataSeq2seq.tsv
# encoder                          data/devDataSeq2seq.tsv
# learning_rate_scheduler          data/devDataSeq2seq.tsv
# max_decoding_steps               data/devDataSeq2seq.tsv
# num_epochs                       data/devDataSeq2seq.tsv
# optimizer                        data/devDataSeq2seq.tsv
# padding_noise                    data/devDataSeq2seq.tsv
# should_log_learning_rate         data/devDataSeq2seq.tsv
# should_log_parameter_statistics  data/devDataSeq2seq.tsv
# sorting_keys                     data/devDataSeq2seq.tsv
# source_embedder                  data/devDataSeq2seq.tsv
# source_token_indexers            data/devDataSeq2seq.tsv
# target_embedding_dim             data/devDataSeq2seq.tsv
# target_namespace                 data/devDataSeq2seq.tsv
# type                             data/devDataSeq2seq.tsv
# validation_metric                data/devDataSeq2seq.tsv

# %%
jsonData = pd.read_json('data/IR_new_val.json',lines=True)

# %%
jsonData.values.tolist()
# Out:
# [[26.58261489868164,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Deep',
#     'sea',
#     'animals',
#     '.',
#     '@@SEP@@',
#     'deep',
#     'sea',
#     'animals',
#     'live',
#     'deep',
#     'in',
#     'the',
#     'ocean'],
#    'src_id': '8-376:0:0',
#    'target_tokens': ['-']},
#   [-6.221836566925049, -6.344954490661621, -6.806394100189209],
#   [['Deep', 'sea', 'fish', 'are', 'deep', 'in', 'the', 'ocean'],
#    ['Deep', 'sea', 'fish', 'are', 'Deep', 'of', 'the', 'ocean'],
#    ['Deep', 'sea', 'fish', 'are', 'Deep', 'sea', 'fish']],
#   [[4607, 195, 113, 12, 575, 10, 6, 111, 3],
#    [4607, 195, 113, 12, 4607, 7, 6, 111, 3],
#    [4607, 195, 113, 12, 4607, 195, 113, 3, 3]]],
#  [28.228389739990234,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Deep',
#     'sea',
#     'animals',
#     '.',
#     '@@SEP@@',
#     'remora',
#     'fish',
#     'eat',
#     'food',
#     'by',
#     'attaching',
#     'themselves',
#     'to',
#     'sharks',
#     'and',
#     'eating',
#     'the',
#     'food',
#     'left',
#     'behind'],
#    'src_id': '8-376:0:1',
#    'target_tokens': ['-']},
#   [-4.544595241546631, -6.033432960510254, -8.446184158325195],
#   [['remora', 'fish', 'are', 'Deep', 'sea', 'animals'],
#    ['remora', 'fish', 'are', 'as', 'Deep', 'sea', 'animals'],
#    ['remora',
#     'fish',
#     'are',
#     'known',
#     'as',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean']],
#   [[1767, 113, 12, 4607, 195, 27, 3, 3, 3, 3, 3],
#    [1767, 113, 12, 105, 4607, 195, 27, 3, 3, 3, 3],
#    [1767, 113, 12, 4312, 105, 6, 277, 7, 6, 111, 3]]],
#  [28.196767807006836,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Deep',
#     'sea',
#     'animals',
#     '.',
#     '@@SEP@@',
#     'a',
#     'fish',
#     'lives',
#     'in',
#     'water'],
#    'src_id': '8-376:0:2',
#    'target_tokens': ['-']},
#   [-3.199810028076172, -4.549784183502197, -4.703963756561279],
#   [['fish', 'are', 'Deep', 'sea', 'animals'],
#    ['a', 'fish', 'are', 'Deep', 'sea', 'animals'],
#    ['a', 'fish', 'is', 'Deep', 'sea', 'animals']],
#   [[113, 12, 4607, 195, 27, 3, 3],
#    [4, 113, 12, 4607, 195, 27, 3],
#    [4, 113, 5, 4607, 195, 27, 3]]],
#  [25.849336624145508,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Deep',
#     'sea',
#     'animals',
#     '.',
#     '@@SEP@@',
#     'oceans',
#     'cover',
#     '70',
#     '%',
#     'of',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'earth'],
#    'src_id': '8-376:0:3',
#    'target_tokens': ['-']},
#   [-3.455992221832275, -4.8549065589904785, -9.251827239990234],
#   [['oceans', 'are', 'Deep', 'sea', 'animals'],
#    ['oceans', 'are', 'Deep', 'sea'],
#    ['Deep',
#     'sea',
#     'animals',
#     'is',
#     'the',
#     '%',
#     'of',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'earth']],
#   [[482, 12, 4607, 195, 27, 3, 3, 3, 3, 3, 3, 3, 3],
#    [482, 12, 4607, 195, 3, 3, 3, 3, 3, 3, 3, 3, 3],
#    [4607, 195, 27, 5, 6, 2095, 7, 6, 277, 7, 6, 83, 3]]],
#  [26.486034393310547,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Deep',
#     'sea',
#     'animals',
#     '.',
#     '@@SEP@@',
#     'aquatic',
#     'animals',
#     'live',
#     'in',
#     'bodies',
#     'of',
#     'water'],
#    'src_id': '8-376:0:4',
#    'target_tokens': ['-']},
#   [-3.869472980499267, -4.15154218673706, -4.615202903747559],
#   [['angler', 'are', 'aquatic', 'animals'],
#    ['Deep', 'sea', 'animals', 'is', 'water'],
#    ['Deep', 'sea', 'animals', 'is', 'aquatic', 'animals']],
#   [[1852, 12, 426, 27, 3, 3, 3],
#    [4607, 195, 27, 5, 13, 3, 3],
#    [4607, 195, 27, 5, 426, 27, 3]]],
#  [27.295242309570312,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Deep',
#     'sea',
#     'animals',
#     '.',
#     '@@SEP@@',
#     'coral',
#     'lives',
#     'in',
#     'the',
#     'ocean'],
#    'src_id': '8-376:0:5',
#    'target_tokens': ['-']},
#   [-3.637320756912231, -3.778700351715088, -4.065980911254883],
#   [['the', 'ocean', 'is', 'Deep', 'sea', 'animals'],
#    ['coral', 'are', 'Deep', 'sea', 'animals'],
#    ['the', 'ocean', 'are', 'Deep', 'sea', 'animals']],
#   [[6, 111, 5, 4607, 195, 27, 3],
#    [1088, 12, 4607, 195, 27, 3, 3],
#    [6, 111, 12, 4607, 195, 27, 3]]],
#  [26.638154983520508,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Deep',
#     'sea',
#     'animals',
#     '.',
#     '@@SEP@@',
#     'producing',
#     'light',
#     'is',
#     'used',
#     'for',
#     'attracting',
#     'prey',
#     'by',
#     'some',
#     'deep',
#     'sea',
#     'animals'],
#    'src_id': '8-376:0:6',
#    'target_tokens': ['-']},
#   [-4.423933982849121, -4.827726364135742, -5.834882736206055],
#   [['Deep', 'sea', 'animals', 'is', 'prey'],
#    ['Deep', 'sea', 'animals', 'is', 'light'],
#    ['Deep', 'sea', 'animals', 'is', 'attracting', 'light']],
#   [[4607, 195, 27, 5, 128, 3, 3],
#    [4607, 195, 27, 5, 21, 3, 3],
#    [4607, 195, 27, 5, 1853, 21, 3]]],
#  [26.124828338623047,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Deep',
#     'sea',
#     'animals',
#     '.',
#     '@@SEP@@',
#     'mimicry',
#     'is',
#     'used',
#     'for',
#     'avoiding',
#     'predators',
#     'by',
#     'animals',
#     'by',
#     'camouflaging',
#     'as',
#     'a',
#     'dangerous',
#     'animal'],
#    'src_id': '8-376:0:7',
#    'target_tokens': ['-']},
#   [-4.527285099029541, -5.155824661254883, -6.348457336425781],
#   [['mimicry', 'is', 'Deep', 'sea', 'animals'],
#    ['mimicry', 'is', 'Deep', 'sea'],
#    ['angler', 'fish', 'are', 'a', 'dangerous', 'animal']],
#   [[3432, 5, 4607, 195, 27, 3, 3],
#    [3432, 5, 4607, 195, 3, 3, 3],
#    [1852, 113, 12, 4, 557, 38, 3]]],
#  [27.076618194580078,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Deep',
#     'sea',
#     'animals',
#     '.',
#     '@@SEP@@',
#     'hawks',
#     'eat',
#     'lizards'],
#    'src_id': '8-376:0:8',
#    'target_tokens': ['-']},
#   [-3.066730976104736, -3.839063167572021, -4.692201137542725],
#   [['lizards', 'are', 'Deep', 'sea', 'animals'],
#    ['lizards', 'is', 'Deep', 'sea', 'animals'],
#    ['angler', 'fish', 'are', 'lizards']],
#   [[342, 12, 4607, 195, 27, 3],
#    [342, 5, 4607, 195, 27, 3],
#    [1852, 113, 12, 342, 3, 3]]],
#  [13.724803924560547,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Deep',
#     'sea',
#     'animals',
#     '.',
#     '@@SEP@@',
#     'warm',
#     '-',
#     'weather',
#     'organisms',
#     'live',
#     'in',
#     'warm',
#     'climates'],
#    'src_id': '8-376:0:9',
#    'target_tokens': ['-']},
#   [-4.042502403259277, -4.946980953216553, -5.879393577575684],
#   [['Deep', 'sea', 'animals', 'is', 'warm'],
#    ['Deep', 'sea', 'animals', 'is', 'warm', 'climates'],
#    ['Deep', 'sea', 'animals', 'is', 'in', 'warm', 'climates']],
#   [[4607, 195, 27, 5, 85, 3, 3, 3],
#    [4607, 195, 27, 5, 85, 1345, 3, 3],
#    [4607, 195, 27, 5, 10, 85, 1345, 3]]],
#  [28.33110809326172,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'fish',
#     '.',
#     '@@SEP@@',
#     'remora',
#     'fish',
#     'eat',
#     'food',
#     'by',
#     'attaching',
#     'themselves',
#     'to',
#     'sharks',
#     'and',
#     'eating',
#     'the',
#     'food',
#     'left',
#     'behind'],
#    'src_id': '8-376:1:0',
#    'target_tokens': ['-']},
#   [-3.76240587234497, -4.711211204528809, -6.458358287811279],
#   [['remora', 'fish', 'are', 'fish'],
#    ['remora', 'fish', 'are', 'as', 'fish'],
#    ['remora', 'fish', 'are', 'as', 'fish', '.']],
#   [[1767, 113, 12, 113, 3, 3, 3],
#    [1767, 113, 12, 105, 113, 3, 3],
#    [1767, 113, 12, 105, 113, 31, 3]]],
#  [28.2628173828125,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'fish',
#     '.',
#     '@@SEP@@',
#     'a',
#     'fish',
#     'lives',
#     'in',
#     'water'],
#    'src_id': '8-376:1:1',
#    'target_tokens': ['-']},
#   [-2.9991836547851562, -3.499753713607788, -3.688241958618164],
#   [['fish', 'are', 'fish'],
#    ['fish', 'are', 'water'],
#    ['fish', 'are', 'a', 'fish']],
#   [[113, 12, 113, 3, 3], [113, 12, 13, 3, 3], [113, 12, 4, 113, 3]]],
#  [26.17740249633789,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'fish',
#     '.',
#     '@@SEP@@',
#     'mimicry',
#     'is',
#     'used',
#     'for',
#     'avoiding',
#     'predators',
#     'by',
#     'animals',
#     'by',
#     'camouflaging',
#     'as',
#     'a',
#     'dangerous',
#     'animal'],
#    'src_id': '8-376:1:2',
#    'target_tokens': ['-']},
#   [-4.097483158111572, -4.770934104919434, -5.927364349365234],
#   [['fish', 'is', 'a', 'dangerous', 'animal'],
#    ['angler', 'are', 'a', 'dangerous', 'animal'],
#    ['angler', 'fish', 'are', 'a', 'dangerous', 'animal']],
#   [[113, 5, 4, 557, 38, 3, 3],
#    [1852, 12, 4, 557, 38, 3, 3],
#    [1852, 113, 12, 4, 557, 38, 3]]],
#  [25.918991088867188,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'fish',
#     '.',
#     '@@SEP@@',
#     'oceans',
#     'cover',
#     '70',
#     '%',
#     'of',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'earth'],
#    'src_id': '8-376:1:3',
#    'target_tokens': ['-']},
#   [-3.222518444061279, -5.848535060882568, -8.493575096130371],
#   [['oceans', 'are', 'fish'],
#    ['angler', 'fish', 'are', 'as', 'fish'],
#    ['fish', 'are', 'the', '%', 'of', 'the', 'surface', 'of', 'the', 'ocean']],
#   [[482, 12, 113, 3, 3, 3, 3, 3, 3, 3, 3],
#    [1852, 113, 12, 105, 113, 3, 3, 3, 3, 3, 3],
#    [113, 12, 6, 2095, 7, 6, 277, 7, 6, 111, 3]]],
#  [26.89101791381836,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'fish',
#     '.',
#     '@@SEP@@',
#     'adult',
#     'amphibians',
#     'live',
#     'on',
#     'land'],
#    'src_id': '8-376:1:4',
#    'target_tokens': ['-']},
#   [-2.997124195098877, -3.161115646362304, -5.868060111999512],
#   [['fish', 'are', 'land'],
#    ['fish', 'is', 'land'],
#    ['angler', 'fish', 'are', 'on', 'land']],
#   [[113, 12, 162, 3, 3, 3],
#    [113, 5, 162, 3, 3, 3],
#    [1852, 113, 12, 34, 162, 3]]],
#  [25.740108489990234,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'fish',
#     '.',
#     '@@SEP@@',
#     'if',
#     'an',
#     'animal',
#     'eats',
#     'another',
#     'animal',
#     'then',
#     'that',
#     'animal',
#     'is',
#     'a',
#     'carnivore',
#     'or',
#     'omnivore',
#     'or',
#     'predator'],
#    'src_id': '8-376:1:5',
#    'target_tokens': ['-']},
#   [-3.9560546875, -4.83803653717041, -5.115250110626221],
#   [['fish', 'is', 'a', 'animal'],
#    ['angler', 'are', 'a', 'animal'],
#    ['fish', 'is', 'a', 'carnivore']],
#   [[113, 5, 4, 38, 3], [1852, 12, 4, 38, 3], [113, 5, 4, 4621, 3]]],
#  [24.350616455078125,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'fish',
#     '.',
#     '@@SEP@@',
#     'adaptation',
#     'is',
#     'when',
#     'an',
#     'organism',
#     'develops',
#     'a',
#     'trait',
#     'over',
#     'time',
#     'for',
#     'survival'],
#    'src_id': '8-376:1:6',
#    'target_tokens': ['-']},
#   [-3.925891637802124, -4.106675148010254, -5.309638023376465],
#   [['fish', 'is', 'a', 'organism'],
#    ['angler', 'are', 'an', 'organism'],
#    ['angler', 'fish', 'are', 'an', 'organism']],
#   [[113, 5, 4, 95, 3, 3],
#    [1852, 12, 15, 95, 3, 3],
#    [1852, 113, 12, 15, 95, 3]]],
#  [26.600339889526367,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'fish',
#     '.',
#     '@@SEP@@',
#     'young',
#     'amphibians',
#     'breathe',
#     'through',
#     'gills'],
#    'src_id': '8-376:1:7',
#    'target_tokens': ['-']},
#   [-3.340362310409546, -3.619625329971313, -3.99299955368042],
#   [['fish', 'are', 'young', 'amphibians'],
#    ['fish', 'is', 'young', 'amphibians'],
#    ['young', 'amphibians', 'are', 'fish']],
#   [[113, 12, 425, 620, 3], [113, 5, 425, 620, 3], [425, 620, 12, 113, 3]]],
#  [27.03192901611328,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'fish',
#     '.',
#     '@@SEP@@',
#     'hawks',
#     'eat',
#     'lizards'],
#    'src_id': '8-376:1:8',
#    'target_tokens': ['-']},
#   [-2.575067520141601, -3.658588171005249, -4.217473983764648],
#   [['lizards', 'are', 'fish'],
#    ['lizards', 'is', 'fish'],
#    ['angler', 'fish', 'are', 'lizards']],
#   [[342, 12, 113, 3, 3], [342, 5, 113, 3, 3], [1852, 113, 12, 342, 3]]],
#  [26.74848175048828,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'fish',
#     '.',
#     '@@SEP@@',
#     'aquatic',
#     'animals',
#     'live',
#     'in',
#     'bodies',
#     'of',
#     'water'],
#    'src_id': '8-376:1:9',
#    'target_tokens': ['-']},
#   [-3.792976856231689, -4.177700042724609, -4.402804374694824],
#   [['fish', 'are', 'aquatic', 'animals'],
#    ['fish', 'is', 'aquatic', 'animals'],
#    ['angler', 'fish', 'are', 'aquatic', 'animals']],
#   [[113, 12, 426, 27, 3, 3],
#    [113, 5, 426, 27, 3, 3],
#    [1852, 113, 12, 426, 27, 3]]],
#  [27.05868911743164,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Long',
#     'Sea',
#     'Fish',
#     '.',
#     '@@SEP@@',
#     'remora',
#     'fish',
#     'eat',
#     'food',
#     'by',
#     'attaching',
#     'themselves',
#     'to',
#     'sharks',
#     'and',
#     'eating',
#     'the',
#     'food',
#     'left',
#     'behind'],
#    'src_id': '8-376:2:0',
#    'target_tokens': ['-']},
#   [-3.959466934204101, -4.498621940612793, -5.055077075958252],
#   [['sharks', 'are', 'Long', 'Sea', 'Fish'],
#    ['food', 'are', 'Long', 'Sea', 'Fish'],
#    ['remora', 'fish', 'are', 'Long', 'Sea', 'Fish']],
#   [[754, 12, 4607, 591, 2054, 3, 3],
#    [20, 12, 4607, 591, 2054, 3, 3],
#    [1767, 113, 12, 4607, 591, 2054, 3]]],
#  [27.480785369873047,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Long',
#     'Sea',
#     'Fish',
#     '.',
#     '@@SEP@@',
#     'a',
#     'fish',
#     'lives',
#     'in',
#     'water'],
#    'src_id': '8-376:2:1',
#    'target_tokens': ['-']},
#   [-3.153780937194824, -3.863290309906006, -5.548233985900879],
#   [['fish', 'are', 'Long', 'Sea', 'Fish'],
#    ['water', 'are', 'Long', 'Sea', 'Fish'],
#    ['angler', 'fish', 'are', 'Long', 'Sea', 'Fish']],
#   [[113, 12, 4607, 591, 2054, 3, 3],
#    [13, 12, 4607, 591, 2054, 3, 3],
#    [1852, 113, 12, 4607, 591, 2054, 3]]],
#  [25.01830291748047,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Long',
#     'Sea',
#     'Fish',
#     '.',
#     '@@SEP@@',
#     'oceans',
#     'cover',
#     '70',
#     '%',
#     'of',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'earth'],
#    'src_id': '8-376:2:2',
#    'target_tokens': ['-']},
#   [-3.61776065826416, -5.219014167785644, -6.275291442871094],
#   [['oceans', 'are', 'Long', 'Sea', 'Fish'],
#    ['angler', 'fish', 'are', 'Long', 'Sea', 'Fish'],
#    ['angler', 'fish', 'are', 'as', 'Long', 'Sea', 'Fish']],
#   [[482, 12, 4607, 591, 2054, 3, 3, 3],
#    [1852, 113, 12, 4607, 591, 2054, 3, 3],
#    [1852, 113, 12, 105, 4607, 591, 2054, 3]]],
#  [26.109760284423828,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Long',
#     'Sea',
#     'Fish',
#     '.',
#     '@@SEP@@',
#     'large',
#     'fins',
#     'can',
#     'be',
#     'used',
#     'to',
#     'move',
#     'quickly',
#     'through',
#     'water'],
#    'src_id': '8-376:2:3',
#    'target_tokens': ['-']},
#   [-3.729036569595337, -3.769058465957641, -4.439294815063477],
#   [['angler', 'are', 'large', 'fins'],
#    ['Long', 'Sea', 'Fish', 'is', 'large', 'fins'],
#    ['Long', 'Sea', 'Fish', 'is', 'water']],
#   [[1852, 12, 199, 546, 3, 3, 3],
#    [4607, 591, 2054, 5, 199, 546, 3],
#    [4607, 591, 2054, 5, 13, 3, 3]]],
#  [25.919153213500977,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Long',
#     'Sea',
#     'Fish',
#     '.',
#     '@@SEP@@',
#     'adult',
#     'amphibians',
#     'live',
#     'on',
#     'land'],
#    'src_id': '8-376:2:4',
#    'target_tokens': ['-']},
#   [-3.8516664505004883, -5.80336856842041, -5.9126715660095215],
#   [['land', 'are', 'Long', 'Sea', 'Fish'],
#    ['angler', 'fish', 'are', 'on', 'land'],
#    ['angler', 'fish', 'are', 'Long', 'Sea', 'Fish']],
#   [[162, 12, 4607, 591, 2054, 3, 3],
#    [1852, 113, 12, 34, 162, 3, 3],
#    [1852, 113, 12, 4607, 591, 2054, 3]]],
#  [25.549541473388672,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Long',
#     'Sea',
#     'Fish',
#     '.',
#     '@@SEP@@',
#     'mimicry',
#     'is',
#     'used',
#     'for',
#     'avoiding',
#     'predators',
#     'by',
#     'animals',
#     'by',
#     'camouflaging',
#     'as',
#     'a',
#     'dangerous',
#     'animal'],
#    'src_id': '8-376:2:5',
#    'target_tokens': ['-']},
#   [-4.100171566009521, -5.011744022369385, -5.469197750091553],
#   [['Long', 'Sea', 'Fish', 'is', 'a', 'dangerous', 'animal'],
#    ['Long', 'Sea', 'Fish', 'is', 'predators'],
#    ['Long', 'Sea', 'Fish', 'is', 'a', 'predators']],
#   [[4607, 591, 2054, 5, 4, 557, 38, 3],
#    [4607, 591, 2054, 5, 55, 3, 3, 3],
#    [4607, 591, 2054, 5, 4, 55, 3, 3]]],
#  [25.781389236450195,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Long',
#     'Sea',
#     'Fish',
#     '.',
#     '@@SEP@@',
#     'young',
#     'amphibians',
#     'breathe',
#     'through',
#     'gills'],
#    'src_id': '8-376:2:6',
#    'target_tokens': ['-']},
#   [-3.491819381713867, -4.248702526092529, -4.502402305603027],
#   [['Long', 'Sea', 'Fish', 'is', 'young', 'amphibians'],
#    ['Long', 'Sea', 'Fish', 'is', 'gills'],
#    ['Long', 'Sea', 'Fish', 'are', 'young', 'amphibians']],
#   [[4607, 591, 2054, 5, 425, 620, 3],
#    [4607, 591, 2054, 5, 522, 3, 3],
#    [4607, 591, 2054, 12, 425, 620, 3]]],
#  [25.768421173095703,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Long',
#     'Sea',
#     'Fish',
#     '.',
#     '@@SEP@@',
#     'deep',
#     'sea',
#     'animals',
#     'live',
#     'deep',
#     'in',
#     'the',
#     'ocean'],
#    'src_id': '8-376:2:7',
#    'target_tokens': ['-']},
#   [-7.149690628051758, -7.179702281951904, -7.293699264526367],
#   [['angler', 'sea', 'fish', 'are', 'deep', 'in', 'the', 'ocean'],
#    ['angler', 'sea', 'fish', 'live', 'deep', 'in', 'the', 'ocean'],
#    ['angler', 'sea', 'fish', 'are', 'deep']],
#   [[1852, 195, 113, 12, 575, 10, 6, 111, 3],
#    [1852, 195, 113, 123, 575, 10, 6, 111, 3],
#    [1852, 195, 113, 12, 575, 3, 3, 3, 3]]],
#  [14.377132415771484,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Long',
#     'Sea',
#     'Fish',
#     '.',
#     '@@SEP@@',
#     'warm',
#     '-',
#     'weather',
#     'organisms',
#     'live',
#     'in',
#     'warm',
#     'climates'],
#    'src_id': '8-376:2:8',
#    'target_tokens': ['-']},
#   [-3.939550876617431, -4.491252899169922, -5.482717514038086],
#   [['Long', 'Sea', 'Fish', 'is', 'warm'],
#    ['Long', 'Sea', 'Fish', 'is', 'warm', 'climates'],
#    ['Long', 'Sea', 'Fish', 'is', 'in', 'warm', 'climates']],
#   [[4607, 591, 2054, 5, 85, 3, 3, 3],
#    [4607, 591, 2054, 5, 85, 1345, 3, 3],
#    [4607, 591, 2054, 5, 10, 85, 1345, 3]]],
#  [26.10546875,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Long',
#     'Sea',
#     'Fish',
#     '.',
#     '@@SEP@@',
#     'hawks',
#     'eat',
#     'lizards'],
#    'src_id': '8-376:2:9',
#    'target_tokens': ['-']},
#   [-2.622950077056884, -3.551577091217041, -4.547415733337402],
#   [['lizards', 'are', 'Long', 'Sea', 'Fish'],
#    ['lizards', 'is', 'Long', 'Sea', 'Fish'],
#    ['angler', 'fish', 'are', 'lizards']],
#   [[342, 12, 4607, 591, 2054, 3],
#    [342, 5, 4607, 591, 2054, 3],
#    [1852, 113, 12, 342, 3, 3]]],
#  [27.333354949951172,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Far',
#     'Sea',
#     'Animals',
#     '.',
#     '@@SEP@@',
#     'deep',
#     'sea',
#     'animals',
#     'live',
#     'deep',
#     'in',
#     'the',
#     'ocean'],
#    'src_id': '8-376:3:0',
#    'target_tokens': ['-']},
#   [-5.396086692810059, -5.45189619064331, -5.670139789581299],
#   [['Sea', 'Animals', 'is', 'deep'],
#    ['Sea', 'Animals', 'are', 'deep'],
#    ['Sea', 'Animals', 'is', 'deep', 'animals']],
#   [[591, 468, 5, 575, 3, 3],
#    [591, 468, 12, 575, 3, 3],
#    [591, 468, 5, 575, 27, 3]]],
#  [28.300762176513672,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Far',
#     'Sea',
#     'Animals',
#     '.',
#     '@@SEP@@',
#     'remora',
#     'fish',
#     'eat',
#     'food',
#     'by',
#     'attaching',
#     'themselves',
#     'to',
#     'sharks',
#     'and',
#     'eating',
#     'the',
#     'food',
#     'left',
#     'behind'],
#    'src_id': '8-376:3:1',
#    'target_tokens': ['-']},
#   [-8.606239318847656, -9.353081703186035, -11.093732833862305],
#   [['remora',
#     'fish',
#     'are',
#     'known',
#     'as',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean'],
#    ['remora', 'fish', 'are', 'as', 'the', 'surface', 'of', 'the', 'ocean'],
#    ['remora',
#     'fish',
#     'are',
#     'known',
#     'as',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean']],
#   [[1767, 113, 12, 4312, 105, 6, 277, 7, 6, 111, 3, 3, 3, 3],
#    [1767, 113, 12, 105, 6, 277, 7, 6, 111, 3, 3, 3, 3, 3],
#    [1767, 113, 12, 4312, 105, 6, 277, 7, 6, 277, 7, 6, 111, 3]]],
#  [29.031980514526367,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Far',
#     'Sea',
#     'Animals',
#     '.',
#     '@@SEP@@',
#     'a',
#     'fish',
#     'lives',
#     'in',
#     'water'],
#    'src_id': '8-376:3:2',
#    'target_tokens': ['-']},
#   [-3.930920124053955, -4.436865329742432, -5.758230209350586],
#   [['Sea', 'Animals', 'is', 'water'],
#    ['Sea', 'Animals', 'are', 'water'],
#    ['Sea', 'Animals', 'is', 'a', 'water']],
#   [[591, 468, 5, 13, 3, 3],
#    [591, 468, 12, 13, 3, 3],
#    [591, 468, 5, 4, 13, 3]]],
#  [27.837244033813477,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Far',
#     'Sea',
#     'Animals',
#     '.',
#     '@@SEP@@',
#     'aquatic',
#     'animals',
#     'live',
#     'in',
#     'bodies',
#     'of',
#     'water'],
#    'src_id': '8-376:3:3',
#    'target_tokens': ['-']},
#   [-4.6843767166137695, -5.036396980285644, -5.211659431457519],
#   [['Sea', 'Animals', 'is', 'water'],
#    ['Sea', 'Animals', 'is', 'aquatic', 'animals'],
#    ['Sea', 'Animals', 'are', 'aquatic', 'animals']],
#   [[591, 468, 5, 13, 3, 3],
#    [591, 468, 5, 426, 27, 3],
#    [591, 468, 12, 426, 27, 3]]],
#  [26.939815521240234,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Far',
#     'Sea',
#     'Animals',
#     '.',
#     '@@SEP@@',
#     'oceans',
#     'cover',
#     '70',
#     '%',
#     'of',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'earth'],
#    'src_id': '8-376:3:4',
#    'target_tokens': ['-']},
#   [-8.732513427734375, -9.942279815673828, -10.950806617736816],
#   [['angler',
#     'fish',
#     'are',
#     'known',
#     'as',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean'],
#    ['Sea',
#     'Animals',
#     'is',
#     'the',
#     '%',
#     'of',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'earth'],
#    ['angler',
#     'fish',
#     'are',
#     'known',
#     'as',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean']],
#   [[1852, 113, 12, 4312, 105, 6, 277, 7, 6, 111, 3, 3, 3, 3],
#    [591, 468, 5, 6, 2095, 7, 6, 277, 7, 6, 83, 3, 3, 3],
#    [1852, 113, 12, 4312, 105, 6, 277, 7, 6, 277, 7, 6, 111, 3]]],
#  [27.20810890197754,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Far',
#     'Sea',
#     'Animals',
#     '.',
#     '@@SEP@@',
#     'mimicry',
#     'is',
#     'used',
#     'for',
#     'avoiding',
#     'predators',
#     'by',
#     'animals',
#     'by',
#     'camouflaging',
#     'as',
#     'a',
#     'dangerous',
#     'animal'],
#    'src_id': '8-376:3:5',
#    'target_tokens': ['-']},
#   [-8.978816032409668, -9.810859680175781, -15.50568675994873],
#   [['angler', 'are', 'known', 'as', 'the', 'surface', 'of', 'the', 'ocean'],
#    ['angler',
#     'fish',
#     'are',
#     'known',
#     'as',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean'],
#    ['angler',
#     'fish',
#     'are',
#     'known',
#     'as',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     'is',
#     'as',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean']],
#   [[1852, 12, 4312, 105, 6, 277, 7, 6, 111, 3, 3, 3, 3, 3, 3, 3, 3, 3],
#    [1852, 113, 12, 4312, 105, 6, 277, 7, 6, 111, 3, 3, 3, 3, 3, 3, 3, 3],
#    [1852,
#     113,
#     12,
#     4312,
#     105,
#     6,
#     277,
#     7,
#     6,
#     111,
#     5,
#     105,
#     6,
#     277,
#     7,
#     6,
#     111,
#     3]]],
#  [15.435254096984863,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Far',
#     'Sea',
#     'Animals',
#     '.',
#     '@@SEP@@',
#     'warm',
#     '-',
#     'weather',
#     'organisms',
#     'live',
#     'in',
#     'warm',
#     'climates'],
#    'src_id': '8-376:3:6',
#    'target_tokens': ['-']},
#   [-4.429581642150879, -4.584733009338379, -6.524413108825684],
#   [['Sea', 'Animals', 'is', 'warm'],
#    ['Sea', 'Animals', 'are', 'warm'],
#    ['Sea', 'Animals', 'are', 'in', 'warm', 'climates']],
#   [[591, 468, 5, 85, 3, 3, 3],
#    [591, 468, 12, 85, 3, 3, 3],
#    [591, 468, 12, 10, 85, 1345, 3]]],
#  [27.89666748046875,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Far',
#     'Sea',
#     'Animals',
#     '.',
#     '@@SEP@@',
#     'coral',
#     'lives',
#     'in',
#     'the',
#     'ocean'],
#    'src_id': '8-376:3:7',
#    'target_tokens': ['-']},
#   [-5.795767784118652, -6.596743583679199, -6.9030585289001465],
#   [['the', 'ocean', 'is', 'the', 'Sea', 'Animals'],
#    ['the', 'ocean', 'is', 'as', 'the', 'Sea', 'Animals'],
#    ['the', 'ocean', 'are', 'as', 'the', 'Sea', 'Animals']],
#   [[6, 111, 5, 6, 591, 468, 3, 3],
#    [6, 111, 5, 105, 6, 591, 468, 3],
#    [6, 111, 12, 105, 6, 591, 468, 3]]],
#  [27.771648406982422,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Far',
#     'Sea',
#     'Animals',
#     '.',
#     '@@SEP@@',
#     'adult',
#     'amphibians',
#     'live',
#     'on',
#     'land'],
#    'src_id': '8-376:3:8',
#    'target_tokens': ['-']},
#   [-3.92455244064331, -4.209097385406494, -5.079732894897461],
#   [['Sea', 'Animals', 'is', 'land'],
#    ['Sea', 'Animals', 'are', 'land'],
#    ['Sea', 'Animals', 'are', 'on', 'land']],
#   [[591, 468, 5, 162, 3, 3],
#    [591, 468, 12, 162, 3, 3],
#    [591, 468, 12, 34, 162, 3]]],
#  [27.81024742126465,
#   {'source_tokens': ['Frilled',
#     'sharks',
#     'and',
#     'angler',
#     'fish',
#     'live',
#     'far',
#     'beneath',
#     'the',
#     'surface',
#     'of',
#     'the',
#     'ocean',
#     ',',
#     'which',
#     'is',
#     'why',
#     'they',
#     'are',
#     'known',
#     'as',
#     'Far',
#     'Sea',
#     'Animals',
#     '.',
#     '@@SEP@@',
#     'hawks',
#     'eat',
#     'lizards'],
#    'src_id': '8-376:3:9',
#    'target_tokens': ['-']},
#   [-4.173574447631836, -4.272965431213379, -5.708547592163086],
#   [['Sea', 'Animals', 'is', 'lizards'],
#    ['Sea', 'Animals', 'are', 'lizards'],
#    ['angler', 'fish', 'are', 'lizards']],
#   [[591, 468, 5, 342, 3], [591, 468, 12, 342, 3], [1852, 113, 12, 342, 3]]],
#  [28.102184295654297,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     '@@SEP@@',
#     'a',
#     'beach',
#     'ball',
#     'contains',
#     'gas'],
#    'src_id': '7-57:0:0',
#    'target_tokens': ['-']},
#   [-3.230949163436889, -3.405908823013305, -4.099150657653809],
#   [['gas', 'is', 'standard', 'weight', 'and', 'size'],
#    ['Gas', 'is', 'standard', 'weight', 'and', 'size'],
#    ['gas', 'is', 'standard', 'weight']],
#   [[59, 5, 2296, 160, 19, 327, 3],
#    [4586, 5, 2296, 160, 19, 327, 3],
#    [59, 5, 2296, 160, 3, 3, 3]]],
#  [27.921485900878906,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     '@@SEP@@',
#     'the',
#     'circulatory',
#     'system',
#     'transports',
#     'blood',
#     'throughout',
#     'the',
#     'body'],
#    'src_id': '7-57:0:1',
#    'target_tokens': ['-']},
#   [-3.720408678054809, -3.786189079284668, -9.081485748291016],
#   [['blood', 'is', 'standard', 'weight', 'and', 'size'],
#    ['the', 'circulatory', 'system', 'is', 'the', 'circulatory', 'system'],
#    ['the',
#     'circulatory',
#     'system',
#     'is',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size']],
#   [[432, 5, 2296, 160, 19, 327, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3],
#    [6, 1068, 164, 5, 6, 1068, 164, 3, 3, 3, 3, 3, 3, 3, 3, 3],
#    [6, 1068, 164, 5, 2023, 1730, 351, 18, 19, 62, 5, 2296, 160, 19, 327, 3]]],
#  [26.98841094970703,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     '@@SEP@@',
#     'matter',
#     'in',
#     'the',
#     'gas',
#     'phase',
#     'has',
#     'variable',
#     'volume'],
#    'src_id': '7-57:0:2',
#    'target_tokens': ['-']},
#   [-4.166563034057617, -5.146440029144287, -5.859407424926758],
#   [['Gas', 'is', 'standard', 'weight', 'and', 'size'],
#    ['gas', 'volume', 'is', 'standard', 'weight', 'and', 'size'],
#    ['gas', 'volume', 'is', 'standard', 'weight']],
#   [[4586, 5, 2296, 160, 19, 327, 3, 3],
#    [59, 530, 5, 2296, 160, 19, 327, 3],
#    [59, 530, 5, 2296, 160, 3, 3, 3]]],
#  [26.5914306640625,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     '@@SEP@@',
#     'matter',
#     'in',
#     'the',
#     'liquid',
#     'phase',
#     'has',
#     'definite',
#     'volume'],
#    'src_id': '7-57:0:3',
#    'target_tokens': ['-']},
#   [-3.825232744216919, -5.090105533599853, -9.115904808044434],
#   [['liquid', 'is', 'standard', 'weight', 'and', 'size'],
#    ['liquid', 'is', 'standard', 'weight'],
#    ['liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     'is',
#     'the',
#     'liquid']],
#   [[62, 5, 2296, 160, 19, 327, 3, 3, 3, 3],
#    [62, 5, 2296, 160, 3, 3, 3, 3, 3, 3],
#    [62, 5, 2296, 160, 19, 327, 5, 6, 62, 3]]],
#  [27.18988609313965,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     '@@SEP@@',
#     'when',
#     'a',
#     'gas',
#     'in',
#     'an',
#     'open',
#     'container',
#     'evaporates',
#     ',',
#     'that',
#     'gas',
#     'spreads',
#     'out',
#     'into',
#     'the',
#     'air'],
#    'src_id': '7-57:0:4',
#    'target_tokens': ['-']},
#   [-9.116669654846191, -9.886244773864746, -11.900710105895996],
#   [['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size'],
#    ['Gas',
#     'can',
#     'fill',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size'],
#    ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size']],
#   [[4586,
#     14,
#     2023,
#     1730,
#     351,
#     18,
#     19,
#     62,
#     5,
#     2296,
#     160,
#     19,
#     327,
#     3,
#     3,
#     3,
#     3,
#     3],
#    [4586,
#     14,
#     2023,
#     2023,
#     1730,
#     351,
#     18,
#     19,
#     62,
#     5,
#     2296,
#     160,
#     19,
#     327,
#     3,
#     3,
#     3,
#     3],
#    [4586,
#     14,
#     2023,
#     1730,
#     351,
#     18,
#     2023,
#     1730,
#     351,
#     18,
#     19,
#     62,
#     5,
#     2296,
#     160,
#     19,
#     327,
#     3]]],
#  [27.170806884765625,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     '@@SEP@@',
#     'as',
#     'heat',
#     'increases',
#     ',',
#     'a',
#     'flexible',
#     'container',
#     'containing',
#     'gas',
#     'will',
#     'expand'],
#    'src_id': '7-57:0:5',
#    'target_tokens': ['-']},
#   [-3.962822198867798, -5.073139190673828, -7.680296897888184],
#   [['Gas', 'is', 'standard', 'weight', 'and', 'size'],
#    ['Gas', 'is', 'standard', 'weight'],
#    ['Gas', 'is', 'standard', 'weight', 'and', 'size', 'is', 'heat']],
#   [[4586, 5, 2296, 160, 19, 327, 3, 3, 3],
#    [4586, 5, 2296, 160, 3, 3, 3, 3, 3],
#    [4586, 5, 2296, 160, 19, 327, 5, 29, 3]]],
#  [27.371395111083984,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     '@@SEP@@',
#     'a',
#     'graduated',
#     'cylinder',
#     'is',
#     'a',
#     'kind',
#     'of',
#     'instrument',
#     'for',
#     'measuring',
#     'volume',
#     'of',
#     'liquids',
#     'or',
#     'objects'],
#    'src_id': '7-57:0:6',
#    'target_tokens': ['-']},
#   [-10.687718391418457, -11.115288734436035, -13.391275405883789],
#   [['graduated',
#     'cylinder',
#     'is',
#     'a',
#     'Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size'],
#    ['a',
#     'graduated',
#     'cylinder',
#     'is',
#     'a',
#     'Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size'],
#    ['a',
#     'graduated',
#     'cylinder',
#     'is',
#     'a',
#     'Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     'is',
#     'a']],
#   [[1255,
#     885,
#     5,
#     4,
#     4586,
#     14,
#     2023,
#     1730,
#     351,
#     18,
#     19,
#     62,
#     5,
#     2296,
#     160,
#     19,
#     327,
#     3,
#     3,
#     3],
#    [4,
#     1255,
#     885,
#     5,
#     4,
#     4586,
#     14,
#     2023,
#     1730,
#     351,
#     18,
#     19,
#     62,
#     5,
#     2296,
#     160,
#     19,
#     327,
#     3,
#     3],
#    [4,
#     1255,
#     885,
#     5,
#     4,
#     4586,
#     14,
#     2023,
#     1730,
#     351,
#     18,
#     19,
#     62,
#     5,
#     2296,
#     160,
#     19,
#     327,
#     5,
#     4]]],
#  [26.58816909790039,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     '@@SEP@@',
#     'natural',
#     'gas',
#     'is',
#     'a',
#     'nonrenewable',
#     'resource'],
#    'src_id': '7-57:0:7',
#    'target_tokens': ['-']},
#   [-4.413170337677002, -4.415882110595703, -7.252842903137207],
#   [['standard', 'weight', 'is', 'a', 'natural', 'Gas'],
#    ['standard', 'weight', 'is', 'a', 'natural', 'gas'],
#    ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size']],
#   [[2296, 160, 5, 4, 117, 4586, 3, 3, 3, 3, 3, 3, 3, 3],
#    [2296, 160, 5, 4, 117, 59, 3, 3, 3, 3, 3, 3, 3, 3],
#    [4586, 14, 2023, 1730, 351, 18, 19, 62, 5, 2296, 160, 19, 327, 3]]],
#  [27.275917053222656,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     '@@SEP@@',
#     'ethanol',
#     'sometimes',
#     'is',
#     'made',
#     'of',
#     'corn'],
#    'src_id': '7-57:0:8',
#    'target_tokens': ['-']},
#   [-3.575941324234009, -3.652597665786743, -7.054704666137695],
#   [['corn', 'is', 'standard', 'weight', 'and', 'size'],
#    ['ethanol', 'is', 'standard', 'weight', 'and', 'size'],
#    ['corn', 'is', 'standard', 'weight', 'and', 'size', 'is']],
#   [[316, 5, 2296, 160, 19, 327, 3, 3],
#    [1021, 5, 2296, 160, 19, 327, 3, 3],
#    [316, 5, 2296, 160, 19, 327, 5, 3]]],
#  [26.262332916259766,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size',
#     '@@SEP@@',
#     'matter',
#     'with',
#     'variable',
#     'volume',
#     'and',
#     'shape',
#     'assumes',
#     'the',
#     'shape',
#     'and',
#     'size',
#     'of',
#     'its',
#     'entire',
#     'container'],
#    'src_id': '7-57:0:9',
#    'target_tokens': ['-']},
#   [-8.257701873779297, -9.057793617248535, -10.087175369262695],
#   [['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size'],
#    ['Gas',
#     'can',
#     'fill',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight',
#     'and',
#     'size'],
#    ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'standard',
#     'weight']],
#   [[4586, 14, 2023, 1730, 351, 18, 19, 62, 5, 2296, 160, 19, 327, 3, 3],
#    [4586, 14, 2023, 2023, 1730, 351, 18, 19, 62, 5, 2296, 160, 19, 327, 3],
#    [4586, 14, 2023, 1730, 351, 18, 19, 62, 5, 2296, 160, 3, 3, 3, 3]]],
#  [27.62346649169922,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'the',
#     'opposite',
#     'of',
#     'variable',
#     '@@SEP@@',
#     'the',
#     'circulatory',
#     'system',
#     'transports',
#     'blood',
#     'throughout',
#     'the',
#     'body'],
#    'src_id': '7-57:1:0',
#    'target_tokens': ['-']},
#   [-3.8187708854675293, -4.697761535644531, -7.616097450256348],
#   [['the', 'circulatory', 'system', 'is', 'the', 'circulatory', 'system'],
#    ['the',
#     'circulatory',
#     'system',
#     'is',
#     'the',
#     'the',
#     'circulatory',
#     'system'],
#    ['the',
#     'circulatory',
#     'system',
#     'is',
#     'the',
#     'circulatory',
#     'system',
#     'is',
#     'the',
#     'the',
#     'circulatory',
#     'system']],
#   [[6, 1068, 164, 5, 6, 1068, 164, 3, 3, 3, 3, 3, 3],
#    [6, 1068, 164, 5, 6, 6, 1068, 164, 3, 3, 3, 3, 3],
#    [6, 1068, 164, 5, 6, 1068, 164, 5, 6, 6, 1068, 164, 3]]],
#  [26.77130699157715,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'the',
#     'opposite',
#     'of',
#     'variable',
#     '@@SEP@@',
#     'matter',
#     'in',
#     'the',
#     'liquid',
#     'phase',
#     'has',
#     'definite',
#     'volume'],
#    'src_id': '7-57:1:1',
#    'target_tokens': ['-']},
#   [-10.48470401763916, -11.429232597351074, -14.708405494689941],
#   [['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'is',
#     'the',
#     'opposite',
#     'of',
#     'variable'],
#    ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'the',
#     'opposite',
#     'of',
#     'variable'],
#    ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'the',
#     'opposite',
#     'of',
#     'variable']],
#   [[4586, 14, 2023, 1730, 351, 18, 5, 6, 697, 7, 1731, 3, 3, 3, 3, 3, 3, 3],
#    [4586, 14, 2023, 1730, 351, 18, 19, 62, 5, 6, 697, 7, 1731, 3, 3, 3, 3, 3],
#    [4586,
#     14,
#     2023,
#     1730,
#     351,
#     16,
#     2023,
#     1730,
#     351,
#     18,
#     19,
#     62,
#     5,
#     6,
#     697,
#     7,
#     1731,
#     3]]],
#  [27.082035064697266,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'the',
#     'opposite',
#     'of',
#     'variable',
#     '@@SEP@@',
#     'matter',
#     'in',
#     'the',
#     'gas',
#     'phase',
#     'has',
#     'variable',
#     'volume'],
#    'src_id': '7-57:1:2',
#    'target_tokens': ['-']},
#   [-6.168660640716553, -11.275094985961914, -18.227935791015625],
#   [['Gas', 'is', 'the', 'gas', 'phase'],
#    ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'the',
#     'Gas',
#     'phase'],
#    ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'fill',
#     'any',
#     'container',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'the',
#     'the',
#     'Gas',
#     'phase']],
#   [[4586, 5, 6, 59, 443, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3],
#    [4586, 14, 2023, 1730, 351, 16, 5, 6, 4586, 443, 3, 3, 3, 3, 3, 3, 3, 3],
#    [4586,
#     14,
#     2023,
#     1730,
#     351,
#     16,
#     2023,
#     1730,
#     351,
#     18,
#     19,
#     62,
#     5,
#     6,
#     6,
#     4586,
#     443,
#     3]]],
#  [26.756364822387695,
#   {'source_tokens': ['Gas',
#     'can',
#     'fill',
#     'any',
#     'container',
#     'it',
#     'is',
#     'given',
#     ',',
#     'and',
#     'liquid',
#     'is',
#     'the',
#     'opposite',
#     'of',
#     'variable',
#     '@@SEP@@',
#     'when',
#     'a',
# ...
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'full',
#     '@@SEP@@',
#     'the',
#     'winter',
#     'solstice',
#     'is',
#     'on',
#     'june',
#     '21st',
#     'in',
#     'the',
#     'southern',
#     'hemisphere'],
#    'src_id': '7-606:2:0',
#    'target_tokens': ['-']},
#   [-4.725248336791992, -4.991686820983887, -6.128276348114014],
#   [['the',
#     'winter',
#     'solstice',
#     'is',
#     'a',
#     'day',
#     'in',
#     'the',
#     'southern',
#     'hemisphere'],
#    ['the', 'winter', 'solstice', 'is', 'a', 'day', 'the', 'moon'],
#    ['the',
#     'winter',
#     'solstice',
#     'is',
#     'a',
#     'day',
#     'in',
#     'the',
#     'southern',
#     'solstice']],
#   [[6, 63, 421, 5, 4, 84, 10, 6, 257, 132, 3],
#    [6, 63, 421, 5, 4, 84, 6, 45, 3, 3, 3],
#    [6, 63, 421, 5, 4, 84, 10, 6, 257, 421, 3]]],
#  [28.40819549560547,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'full',
#     '@@SEP@@',
#     'the',
#     'winter',
#     'solstice',
#     'is',
#     'on',
#     'december',
#     '21st',
#     'in',
#     'the',
#     'northern',
#     'hemisphere'],
#    'src_id': '7-606:2:1',
#    'target_tokens': ['-']},
#   [-4.768472671508789, -5.420703887939453, -5.835421562194824],
#   [['the', 'winter', 'solstice', 'is', 'a', 'day', 'the', 'moon'],
#    ['the',
#     'winter',
#     'solstice',
#     'is',
#     'a',
#     'day',
#     'in',
#     'the',
#     'northern',
#     'hemisphere'],
#    ['the', 'winter', 'solstice', 'is', 'a', 'day', 'the', 'the', 'moon']],
#   [[6, 63, 421, 5, 4, 84, 6, 45, 3, 3, 3],
#    [6, 63, 421, 5, 4, 84, 10, 6, 350, 132, 3],
#    [6, 63, 421, 5, 4, 84, 6, 6, 45, 3, 3]]],
#  [27.66668128967285,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'full',
#     '@@SEP@@',
#     'the',
#     'summer',
#     'solstice',
#     'is',
#     'on',
#     'june',
#     '21st',
#     'in',
#     'the',
#     'northern',
#     'hemisphere'],
#    'src_id': '7-606:2:2',
#    'target_tokens': ['-']},
#   [-4.8301334381103525, -5.326364517211914, -5.897492408752441],
#   [['the', 'summer', 'solstice', 'is', 'a', 'day', 'the', 'moon'],
#    ['the',
#     'summer',
#     'solstice',
#     'is',
#     'a',
#     'day',
#     'in',
#     'the',
#     'northern',
#     'hemisphere'],
#    ['the', 'summer', 'solstice', 'is', 'a', 'day', 'in', 'the', 'moon']],
#   [[6, 127, 421, 5, 4, 84, 6, 45, 3, 3, 3],
#    [6, 127, 421, 5, 4, 84, 10, 6, 350, 132, 3],
#    [6, 127, 421, 5, 4, 84, 10, 6, 45, 3, 3]]],
#  [27.956579208374023,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'full',
#     '@@SEP@@',
#     'the',
#     'amount',
#     'of',
#     'daylight',
#     'is',
#     'least',
#     'on',
#     'the',
#     'winter',
#     'solstice'],
#    'src_id': '7-606:2:3',
#    'target_tokens': ['-']},
#   [-4.213287353515625, -4.61574649810791, -5.951516628265381],
#   [['the', 'moon', 'is', 'the', 'winter', 'solstice'],
#    ['the', 'moon', 'is', 'the', 'amount', 'of', 'daylight'],
#    ['Winter',
#     'solstice',
#     'is',
#     'a',
#     'day',
#     'the',
#     'the',
#     'winter',
#     'solstice']],
#   [[6, 45, 5, 6, 63, 421, 3, 3, 3, 3],
#    [6, 45, 5, 6, 218, 7, 208, 3, 3, 3],
#    [1216, 421, 5, 4, 84, 6, 6, 63, 421, 3]]],
#  [27.875091552734375,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'full',
#     '@@SEP@@',
#     'the',
#     'amount',
#     'of',
#     'daylight',
#     'is',
#     'greatest',
#     'on',
#     'the',
#     'summer',
#     'solstice'],
#    'src_id': '7-606:2:4',
#    'target_tokens': ['-']},
#   [-3.375859260559082, -4.604437828063965, -5.64685583114624],
#   [['the', 'moon', 'is', 'the', 'summer', 'solstice'],
#    ['the', 'moon', 'is', 'the', 'amount', 'of', 'daylight'],
#    ['the', 'moon', 'is', 'the', 'amount', 'of', 'the', 'summer', 'solstice']],
#   [[6, 45, 5, 6, 127, 421, 3, 3, 3, 3],
#    [6, 45, 5, 6, 218, 7, 208, 3, 3, 3],
#    [6, 45, 5, 6, 218, 7, 6, 127, 421, 3]]],
#  [28.149181365966797,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'full',
#     '@@SEP@@',
#     'december',
#     'is',
#     'during',
#     'the',
#     'summer',
#     'in',
#     'the',
#     'southern',
#     'hemisphere'],
#    'src_id': '7-606:2:5',
#    'target_tokens': ['-']},
#   [-5.346168041229248, -6.02649974822998, -6.354968547821045],
#   [['the', 'moon', 'is', 'a', 'day', 'in', 'the', 'southern', 'hemisphere'],
#    ['Winter', 'solstice', 'is', 'a', 'day', 'the', 'moon'],
#    ['Winter',
#     'solstice',
#     'is',
#     'a',
#     'day',
#     'in',
#     'the',
#     'southern',
#     'hemisphere']],
#   [[6, 45, 5, 4, 84, 10, 6, 257, 132, 3],
#    [1216, 421, 5, 4, 84, 6, 45, 3, 3, 3],
#    [1216, 421, 5, 4, 84, 10, 6, 257, 132, 3]]],
#  [27.93570327758789,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'full',
#     '@@SEP@@',
#     'january',
#     'is',
#     'during',
#     'the',
#     'winter',
#     'in',
#     'the',
#     'northern',
#     'hemisphere'],
#    'src_id': '7-606:2:6',
#    'target_tokens': ['-']},
#   [-5.687822341918945, -5.862678527832031, -10.505265235900879],
#   [['the', 'moon', 'is', 'a', 'day', 'in', 'the', 'northern', 'hemisphere'],
#    ['Winter', 'solstice', 'is', 'a', 'day', 'the', 'moon'],
#    ['Winter',
#     'solstice',
#     'is',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'a',
#     'day',
#     'in',
#     'the',
#     'northern',
#     'hemisphere']],
#   [[6, 45, 5, 4, 84, 10, 6, 350, 132, 3, 3, 3, 3, 3, 3],
#    [1216, 421, 5, 4, 84, 6, 45, 3, 3, 3, 3, 3, 3, 3, 3],
#    [1216, 421, 5, 4, 84, 6, 45, 5, 4, 84, 10, 6, 350, 132, 3]]],
#  [27.857158660888672,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'full',
#     '@@SEP@@',
#     'august',
#     'is',
#     'during',
#     'the',
#     'winter',
#     'in',
#     'the',
#     'southern',
#     'hemisphere'],
#    'src_id': '7-606:2:7',
#    'target_tokens': ['-']},
#   [-5.542316436767578, -6.08806562423706, -10.393200874328613],
#   [['Winter', 'solstice', 'is', 'a', 'day', 'the', 'moon'],
#    ['the', 'moon', 'is', 'a', 'day', 'in', 'the', 'southern', 'hemisphere'],
#    ['Winter',
#     'solstice',
#     'is',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'a',
#     'day',
#     'the',
#     'moon']],
#   [[1216, 421, 5, 4, 84, 6, 45, 3, 3, 3, 3, 3, 3],
#    [6, 45, 5, 4, 84, 10, 6, 257, 132, 3, 3, 3, 3],
#    [1216, 421, 5, 4, 84, 6, 45, 5, 4, 84, 6, 45, 3]]],
#  [28.182510375976562,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'full',
#     '@@SEP@@',
#     'december',
#     'is',
#     'during',
#     'the',
#     'winter',
#     'in',
#     'the',
#     'northern',
#     'hemisphere'],
#    'src_id': '7-606:2:8',
#    'target_tokens': ['-']},
#   [-4.329777717590332, -5.942559242248535, -10.755837440490723],
#   [['the', 'moon', 'is', 'the', 'northern', 'hemisphere'],
#    ['Winter', 'solstice', 'is', 'a', 'day', 'the', 'moon'],
#    ['Winter',
#     'solstice',
#     'is',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'a',
#     'day',
#     'in',
#     'the',
#     'northern',
#     'hemisphere']],
#   [[6, 45, 5, 6, 350, 132, 3, 3, 3, 3, 3, 3, 3, 3, 3],
#    [1216, 421, 5, 4, 84, 6, 45, 3, 3, 3, 3, 3, 3, 3, 3],
#    [1216, 421, 5, 4, 84, 6, 45, 5, 4, 84, 10, 6, 350, 132, 3]]],
#  [27.639339447021484,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'moon',
#     'is',
#     'full',
#     '@@SEP@@',
#     'june',
#     'is',
#     'during',
#     'the',
#     'summer',
#     'in',
#     'the',
#     'northern',
#     'hemisphere'],
#    'src_id': '7-606:2:9',
#    'target_tokens': ['-']},
#   [-4.118110179901123, -6.04401683807373, -6.51013708114624],
#   [['the', 'moon', 'is', 'the', 'northern', 'hemisphere'],
#    ['Winter', 'solstice', 'is', 'a', 'day', 'the', 'moon'],
#    ['Winter',
#     'solstice',
#     'is',
#     'a',
#     'day',
#     'in',
#     'the',
#     'northern',
#     'hemisphere']],
#   [[6, 45, 5, 6, 350, 132, 3, 3, 3, 3],
#    [1216, 421, 5, 4, 84, 6, 45, 3, 3, 3],
#    [1216, 421, 5, 4, 84, 10, 6, 350, 132, 3]]],
#  [27.170623779296875,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'darkness',
#     'is',
#     'greatest',
#     '@@SEP@@',
#     'the',
#     'amount',
#     'of',
#     'daylight',
#     'is',
#     'greatest',
#     'on',
#     'the',
#     'summer',
#     'solstice'],
#    'src_id': '7-606:3:0',
#    'target_tokens': ['-']},
#   [-2.969402313232422, -3.8192944526672363, -5.194878101348877],
#   [['darkness', 'is', 'the', 'summer', 'solstice'],
#    ['darkness', 'is', 'the', 'amount', 'of', 'daylight'],
#    ['darkness', 'is', 'the', 'amount', 'of', 'the', 'summer', 'solstice']],
#   [[998, 5, 6, 127, 421, 3, 3, 3, 3],
#    [998, 5, 6, 218, 7, 208, 3, 3, 3],
#    [998, 5, 6, 218, 7, 6, 127, 421, 3]]],
#  [27.37958526611328,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'darkness',
#     'is',
#     'greatest',
#     '@@SEP@@',
#     'the',
#     'amount',
#     'of',
#     'daylight',
#     'is',
#     'least',
#     'on',
#     'the',
#     'winter',
#     'solstice'],
#    'src_id': '7-606:3:1',
#    'target_tokens': ['-']},
#   [-3.524112701416015, -3.873323917388916, -5.681136608123779],
#   [['darkness', 'is', 'the', 'amount', 'of', 'daylight'],
#    ['darkness', 'is', 'the', 'winter', 'solstice'],
#    ['Winter',
#     'solstice',
#     'is',
#     'the',
#     'day',
#     'on',
#     'the',
#     'winter',
#     'solstice']],
#   [[998, 5, 6, 218, 7, 208, 3, 3, 3, 3],
#    [998, 5, 6, 63, 421, 3, 3, 3, 3, 3],
#    [1216, 421, 5, 6, 84, 34, 6, 63, 421, 3]]],
#  [27.940345764160156,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'darkness',
#     'is',
#     'greatest',
#     '@@SEP@@',
#     'the',
#     'winter',
#     'solstice',
#     'is',
#     'on',
#     'june',
#     '21st',
#     'in',
#     'the',
#     'southern',
#     'hemisphere'],
#    'src_id': '7-606:3:2',
#    'target_tokens': ['-']},
#   [-5.28572940826416, -6.13091230392456, -6.426042556762695],
#   [['the',
#     'winter',
#     'solstice',
#     'is',
#     'a',
#     'day',
#     'in',
#     'the',
#     'southern',
#     'hemisphere'],
#    ['the', 'winter', 'solstice', 'is', 'on', 'a', 'day', 'the', 'darkness'],
#    ['the',
#     'winter',
#     'solstice',
#     'is',
#     'on',
#     'a',
#     'day',
#     'the',
#     'the',
#     'southern',
#     'hemisphere']],
#   [[6, 63, 421, 5, 4, 84, 10, 6, 257, 132, 3, 3],
#    [6, 63, 421, 5, 34, 4, 84, 6, 998, 3, 3, 3],
#    [6, 63, 421, 5, 34, 4, 84, 6, 6, 257, 132, 3]]],
#  [28.46219825744629,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'darkness',
#     'is',
#     'greatest',
#     '@@SEP@@',
#     'the',
#     'winter',
#     'solstice',
#     'is',
#     'on',
#     'december',
#     '21st',
#     'in',
#     'the',
#     'northern',
#     'hemisphere'],
#    'src_id': '7-606:3:3',
#    'target_tokens': ['-']},
#   [-5.118036270141602, -5.8416595458984375, -7.288984298706055],
#   [['the', 'winter', 'solstice', 'is', 'a', 'day', 'the', 'darkness'],
#    ['the', 'winter', 'solstice', 'is', 'on', 'a', 'day', 'the', 'darkness'],
#    ['the', 'winter', 'solstice', 'is', 'on', 'a', 'day', 'the', 'the', 'day']],
#   [[6, 63, 421, 5, 4, 84, 6, 998, 3, 3, 3],
#    [6, 63, 421, 5, 34, 4, 84, 6, 998, 3, 3],
#    [6, 63, 421, 5, 34, 4, 84, 6, 6, 84, 3]]],
#  [27.408103942871094,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'darkness',
#     'is',
#     'greatest',
#     '@@SEP@@',
#     'the',
#     'summer',
#     'solstice',
#     'is',
#     'on',
#     'june',
#     '21st',
#     'in',
#     'the',
#     'northern',
#     'hemisphere'],
#    'src_id': '7-606:3:4',
#    'target_tokens': ['-']},
#   [-3.008872032165527, -5.704594612121582, -6.439900398254394],
#   [['darkness', 'is', 'the', 'northern', 'hemisphere'],
#    ['the', 'summer', 'solstice', 'is', 'a', 'day', 'the', 'darkness'],
#    ['the', 'summer', 'solstice', 'is', 'on', 'a', 'day', 'the', 'darkness']],
#   [[998, 5, 6, 350, 132, 3, 3, 3, 3, 3],
#    [6, 127, 421, 5, 4, 84, 6, 998, 3, 3],
#    [6, 127, 421, 5, 34, 4, 84, 6, 998, 3]]],
#  [27.48688507080078,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'darkness',
#     'is',
#     'greatest',
#     '@@SEP@@',
#     'the',
#     'amount',
#     'of',
#     'daylight',
#     'is',
#     'greatest',
#     'in',
#     'the',
#     'summer'],
#    'src_id': '7-606:3:5',
#    'target_tokens': ['-']},
#   [-2.581234931945801, -3.391425848007202, -5.029408454895019],
#   [['darkness', 'is', 'the', 'summer'],
#    ['darkness', 'is', 'in', 'the', 'summer'],
#    ['Winter', 'solstice', 'is', 'the', 'summer']],
#   [[998, 5, 6, 127, 3, 3],
#    [998, 5, 10, 6, 127, 3],
#    [1216, 421, 5, 6, 127, 3]]],
#  [27.875932693481445,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'darkness',
#     'is',
#     'greatest',
#     '@@SEP@@',
#     'january',
#     'is',
#     'during',
#     'the',
#     'winter',
#     'in',
#     'the',
#     'northern',
#     'hemisphere'],
#    'src_id': '7-606:3:6',
#    'target_tokens': ['-']},
#   [-4.711994171142578, -7.637695789337158, -7.934021949768066],
#   [['darkness', 'is', 'the', 'january'],
#    ['the',
#     'northern',
#     'hemisphere',
#     'is',
#     'a',
#     'day',
#     'in',
#     'the',
#     'northern',
#     'hemisphere'],
#    ['the',
#     'northern',
#     'hemisphere',
#     'is',
#     'a',
#     'day',
#     'the',
#     'the',
#     'northern',
#     'hemisphere']],
#   [[998, 5, 6, 4597, 3, 3, 3, 3, 3, 3, 3],
#    [6, 350, 132, 5, 4, 84, 10, 6, 350, 132, 3],
#    [6, 350, 132, 5, 4, 84, 6, 6, 350, 132, 3]]],
#  [27.85750389099121,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'darkness',
#     'is',
#     'greatest',
#     '@@SEP@@',
#     'august',
#     'is',
#     'during',
#     'the',
#     'winter',
#     'in',
#     'the',
#     'southern',
#     'hemisphere'],
#    'src_id': '7-606:3:7',
#    'target_tokens': ['-']},
#   [-6.095259189605713, -6.714728355407715, -7.128215312957764],
#   [['Winter', 'solstice', 'is', 'a', 'day', 'the', 'darkness'],
#    ['the', 'southern', 'hemisphere', 'is', 'a', 'day', 'the', 'darkness'],
#    ['the',
#     'southern',
#     'hemisphere',
#     'is',
#     'a',
#     'day',
#     'the',
#     'the',
#     'southern',
#     'hemisphere']],
#   [[1216, 421, 5, 4, 84, 6, 998, 3, 3, 3, 3],
#    [6, 257, 132, 5, 4, 84, 6, 998, 3, 3, 3],
#    [6, 257, 132, 5, 4, 84, 6, 6, 257, 132, 3]]],
#  [27.897823333740234,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'darkness',
#     'is',
#     'greatest',
#     '@@SEP@@',
#     'december',
#     'is',
#     'during',
#     'the',
#     'summer',
#     'in',
#     'the',
#     'southern',
#     'hemisphere'],
#    'src_id': '7-606:3:8',
#    'target_tokens': ['-']},
#   [-4.200590133666992, -7.06201171875, -7.228164672851562],
#   [['darkness', 'is', 'the', 'december'],
#    ['the', 'southern', 'hemisphere', 'is', 'a', 'day', 'the', 'darkness'],
#    ['the',
#     'southern',
#     'hemisphere',
#     'is',
#     'a',
#     'day',
#     'in',
#     'the',
#     'southern',
#     'hemisphere']],
#   [[998, 5, 6, 4597, 3, 3, 3, 3, 3, 3, 3],
#    [6, 257, 132, 5, 4, 84, 6, 998, 3, 3, 3],
#    [6, 257, 132, 5, 4, 84, 10, 6, 257, 132, 3]]],
#  [28.099987030029297,
#   {'source_tokens': ['Winter',
#     'solstice',
#     'occurs',
#     'on',
#     'a',
#     'day',
#     'the',
#     'darkness',
#     'is',
#     'greatest',
#     '@@SEP@@',
#     'the',
#     'amount',
#     'of',
#     'daylight',
#     'is',
#     'least',
#     'in',
#     'the',
#     'winter'],
#    'src_id': '7-606:3:9',
#    'target_tokens': ['-']},
#   [-2.880360603332519, -3.411523342132568, -4.8003482818603525],
#   [['darkness', 'is', 'in', 'the', 'winter'],
#    ['darkness', 'is', 'the', 'winter'],
#    ['darkness', 'is', 'the', 'of', 'daylight']],
#   [[998, 5, 10, 6, 63, 3], [998, 5, 6, 63, 3, 3], [998, 5, 6, 7, 208, 3]]],
#  ...]
